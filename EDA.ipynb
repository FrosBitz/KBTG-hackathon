# %% [markdown]
# # Transaction Data Analysis
#
# This notebook analyzes transaction patterns and creates a graph structure for money laundering detection.

# %%
# !pip install polars
# Out:
# Requirement already satisfied: polars in c:\users\dell\appdata\roaming\python\python313\site-packages (1.30.0)

# %% [markdown]
# ## Setup
#
# Install required library.

# %%
import polars as pl

# df = pl.read_csv('data/HI-Small_Trans.csv')
# Try lazy frame
df = pl.scan_csv('data/HI-Small_Trans.csv')

# %% [markdown]
# ## Load Data
#
# Read transaction data from CSV file.

# %%
df.collect()
# Out:
# shape: (5_078_345, 11)
# ┌────────────┬───────────┬───────────┬─────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Timestamp  ┆ From Bank ┆ Account   ┆ To Bank ┆ … ┆ Amount    ┆ Payment   ┆ Payment   ┆ Is Launde │
# │ ---        ┆ ---       ┆ ---       ┆ ---     ┆   ┆ Paid      ┆ Currency  ┆ Format    ┆ ring      │
# │ str        ┆ i64       ┆ str       ┆ i64     ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │            ┆           ┆           ┆         ┆   ┆ f64       ┆ str       ┆ str       ┆ i64       │
# ╞════════════╪═══════════╪═══════════╪═════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2022/09/01 ┆ 10        ┆ 8000EBD30 ┆ 10      ┆ … ┆ 3697.34   ┆ US Dollar ┆ Reinvestm ┆ 0         │
# │ 00:20      ┆           ┆           ┆         ┆   ┆           ┆           ┆ ent       ┆           │
# │ 2022/09/01 ┆ 3208      ┆ 8000F4580 ┆ 1       ┆ … ┆ 0.01      ┆ US Dollar ┆ Cheque    ┆ 0         │
# │ 00:20      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022/09/01 ┆ 3209      ┆ 8000F4670 ┆ 3209    ┆ … ┆ 14675.57  ┆ US Dollar ┆ Reinvestm ┆ 0         │
# │ 00:00      ┆           ┆           ┆         ┆   ┆           ┆           ┆ ent       ┆           │
# │ 2022/09/01 ┆ 12        ┆ 8000F5030 ┆ 12      ┆ … ┆ 2806.97   ┆ US Dollar ┆ Reinvestm ┆ 0         │
# │ 00:02      ┆           ┆           ┆         ┆   ┆           ┆           ┆ ent       ┆           │
# │ 2022/09/01 ┆ 10        ┆ 8000F5200 ┆ 10      ┆ … ┆ 36682.97  ┆ US Dollar ┆ Reinvestm ┆ 0         │
# │ 00:06      ┆           ┆           ┆         ┆   ┆           ┆           ┆ ent       ┆           │
# │ …          ┆ …         ┆ …         ┆ …       ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2022/09/10 ┆ 54219     ┆ 8148A6631 ┆ 256398  ┆ … ┆ 0.154978  ┆ Bitcoin   ┆ Bitcoin   ┆ 0         │
# │ 23:57      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022/09/10 ┆ 15        ┆ 8148A8671 ┆ 256398  ┆ … ┆ 0.108128  ┆ Bitcoin   ┆ Bitcoin   ┆ 0         │
# │ 23:35      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022/09/10 ┆ 154365    ┆ 8148A6771 ┆ 256398  ┆ … ┆ 0.004988  ┆ Bitcoin   ┆ Bitcoin   ┆ 0         │
# │ 23:52      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022/09/10 ┆ 256398    ┆ 8148A6311 ┆ 256398  ┆ … ┆ 0.038417  ┆ Bitcoin   ┆ Bitcoin   ┆ 0         │
# │ 23:46      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022/09/10 ┆ 154518    ┆ 8148A6091 ┆ 256398  ┆ … ┆ 0.281983  ┆ Bitcoin   ┆ Bitcoin   ┆ 0         │
# │ 23:37      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# └────────────┴───────────┴───────────┴─────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
df = df.with_columns(
    pl.col('Timestamp').str.strptime(pl.Datetime, format='%Y/%m/%d %H:%M')
)

# %% [markdown]
# ## Data Preparation
#
# Convert timestamp column to datetime format.

# %%
df.collect()
# Out:
# shape: (5_078_345, 11)
# ┌────────────┬───────────┬───────────┬─────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Timestamp  ┆ From Bank ┆ Account   ┆ To Bank ┆ … ┆ Amount    ┆ Payment   ┆ Payment   ┆ Is Launde │
# │ ---        ┆ ---       ┆ ---       ┆ ---     ┆   ┆ Paid      ┆ Currency  ┆ Format    ┆ ring      │
# │ datetime[μ ┆ i64       ┆ str       ┆ i64     ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ s]         ┆           ┆           ┆         ┆   ┆ f64       ┆ str       ┆ str       ┆ i64       │
# ╞════════════╪═══════════╪═══════════╪═════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2022-09-01 ┆ 10        ┆ 8000EBD30 ┆ 10      ┆ … ┆ 3697.34   ┆ US Dollar ┆ Reinvestm ┆ 0         │
# │ 00:20:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆ ent       ┆           │
# │ 2022-09-01 ┆ 3208      ┆ 8000F4580 ┆ 1       ┆ … ┆ 0.01      ┆ US Dollar ┆ Cheque    ┆ 0         │
# │ 00:20:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022-09-01 ┆ 3209      ┆ 8000F4670 ┆ 3209    ┆ … ┆ 14675.57  ┆ US Dollar ┆ Reinvestm ┆ 0         │
# │ 00:00:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆ ent       ┆           │
# │ 2022-09-01 ┆ 12        ┆ 8000F5030 ┆ 12      ┆ … ┆ 2806.97   ┆ US Dollar ┆ Reinvestm ┆ 0         │
# │ 00:02:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆ ent       ┆           │
# │ 2022-09-01 ┆ 10        ┆ 8000F5200 ┆ 10      ┆ … ┆ 36682.97  ┆ US Dollar ┆ Reinvestm ┆ 0         │
# │ 00:06:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆ ent       ┆           │
# │ …          ┆ …         ┆ …         ┆ …       ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2022-09-10 ┆ 54219     ┆ 8148A6631 ┆ 256398  ┆ … ┆ 0.154978  ┆ Bitcoin   ┆ Bitcoin   ┆ 0         │
# │ 23:57:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022-09-10 ┆ 15        ┆ 8148A8671 ┆ 256398  ┆ … ┆ 0.108128  ┆ Bitcoin   ┆ Bitcoin   ┆ 0         │
# │ 23:35:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022-09-10 ┆ 154365    ┆ 8148A6771 ┆ 256398  ┆ … ┆ 0.004988  ┆ Bitcoin   ┆ Bitcoin   ┆ 0         │
# │ 23:52:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022-09-10 ┆ 256398    ┆ 8148A6311 ┆ 256398  ┆ … ┆ 0.038417  ┆ Bitcoin   ┆ Bitcoin   ┆ 0         │
# │ 23:46:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022-09-10 ┆ 154518    ┆ 8148A6091 ┆ 256398  ┆ … ┆ 0.281983  ┆ Bitcoin   ┆ Bitcoin   ┆ 0         │
# │ 23:37:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# └────────────┴───────────┴───────────┴─────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# Disregard transaction with Payment Format "Reinvesment"

# %%
df = df.filter(pl.col("Payment Format") != "Reinvestment")

# %% [markdown]
# ## Create Nodes
#
# Build graph nodes from transactions with ID, sender, receiver, time, amount, and label.

# %%
nodes = df.with_row_index("node_id").select([
    pl.col("node_id"),
    pl.col("Account").alias("f_i"),                # From
    pl.col("Account_duplicated_0").alias("b_i"),   # Beneficiary
    pl.col("Timestamp").alias("t_i"),              # Time
    pl.col("Amount Received").alias("a_i"),        # Amount
    pl.col("Is Laundering")                        # Ground truth
])

# %%
nodes.collect()
# Out:
# shape: (4_597_289, 6)
# ┌─────────┬───────────┬───────────┬─────────────────────┬──────────┬───────────────┐
# │ node_id ┆ f_i       ┆ b_i       ┆ t_i                 ┆ a_i      ┆ Is Laundering │
# │ ---     ┆ ---       ┆ ---       ┆ ---                 ┆ ---      ┆ ---           │
# │ u32     ┆ str       ┆ str       ┆ datetime[μs]        ┆ f64      ┆ i64           │
# ╞═════════╪═══════════╪═══════════╪═════════════════════╪══════════╪═══════════════╡
# │ 0       ┆ 8000F4580 ┆ 8000F5340 ┆ 2022-09-01 00:20:00 ┆ 0.01     ┆ 0             │
# │ 1       ┆ 8000EC280 ┆ 8017BF800 ┆ 2022-09-01 00:26:00 ┆ 7.66     ┆ 0             │
# │ 2       ┆ 8000EDEC0 ┆ 80AEF5310 ┆ 2022-09-01 00:21:00 ┆ 383.71   ┆ 0             │
# │ 3       ┆ 8000F4510 ┆ 8011305D0 ┆ 2022-09-01 00:04:00 ┆ 9.82     ┆ 0             │
# │ 4       ┆ 8000F4FE0 ┆ 812ED62E0 ┆ 2022-09-01 00:08:00 ┆ 4.01     ┆ 0             │
# │ …       ┆ …         ┆ …         ┆ …                   ┆ …        ┆ …             │
# │ 4597284 ┆ 8148A6631 ┆ 8148A8711 ┆ 2022-09-10 23:57:00 ┆ 0.154978 ┆ 0             │
# │ 4597285 ┆ 8148A8671 ┆ 8148A8711 ┆ 2022-09-10 23:35:00 ┆ 0.108128 ┆ 0             │
# │ 4597286 ┆ 8148A6771 ┆ 8148A8711 ┆ 2022-09-10 23:52:00 ┆ 0.004988 ┆ 0             │
# │ 4597287 ┆ 8148A6311 ┆ 8148A8711 ┆ 2022-09-10 23:46:00 ┆ 0.038417 ┆ 0             │
# │ 4597288 ┆ 8148A6091 ┆ 8148A8711 ┆ 2022-09-10 23:37:00 ┆ 0.281983 ┆ 0             │
# └─────────┴───────────┴───────────┴─────────────────────┴──────────┴───────────────┘

# %% [markdown]
# ## Create Edges
#
# Connect transactions where one receiver becomes the sender in another transaction.

# %%
edges = nodes.join(
    nodes,
    left_on="b_i", 
    right_on="f_i",
    suffix="_d"
).rename({"node_id": "v_s", "node_id_d": "v_d"})

# %%
# edges.collect()
# Out:
# shape: (355_144_990, 11)
# ┌─────────┬───────────┬───────────┬────────────┬───┬───────────┬────────────┬──────────┬───────────┐
# │ v_s     ┆ f_i       ┆ b_i       ┆ t_i        ┆ … ┆ b_i_d     ┆ t_i_d      ┆ a_i_d    ┆ Is Launde │
# │ ---     ┆ ---       ┆ ---       ┆ ---        ┆   ┆ ---       ┆ ---        ┆ ---      ┆ ring_d    │
# │ u32     ┆ str       ┆ str       ┆ datetime[μ ┆   ┆ str       ┆ datetime[μ ┆ f64      ┆ ---       │
# │         ┆           ┆           ┆ s]         ┆   ┆           ┆ s]         ┆          ┆ i64       │
# ╞═════════╪═══════════╪═══════════╪════════════╪═══╪═══════════╪════════════╪══════════╪═══════════╡
# │ 0       ┆ 8000EBD30 ┆ 8000EBD30 ┆ 2022-09-01 ┆ … ┆ 8000EBD30 ┆ 2022-09-01 ┆ 3697.34  ┆ 0         │
# │         ┆           ┆           ┆ 00:20:00   ┆   ┆           ┆ 00:20:00   ┆          ┆           │
# │ 1124178 ┆ 80F7CE4C0 ┆ 8000EBD30 ┆ 2022-09-02 ┆ … ┆ 8000EBD30 ┆ 2022-09-01 ┆ 3697.34  ┆ 0         │
# │         ┆           ┆           ┆ 00:20:00   ┆   ┆           ┆ 00:20:00   ┆          ┆           │
# │ 1124182 ┆ 80F7D6660 ┆ 8000EBD30 ┆ 2022-09-02 ┆ … ┆ 8000EBD30 ┆ 2022-09-01 ┆ 3697.34  ┆ 0         │
# │         ┆           ┆           ┆ 00:18:00   ┆   ┆           ┆ 00:20:00   ┆          ┆           │
# │ 1624528 ┆ 8000EBBB0 ┆ 8000EBD30 ┆ 2022-09-02 ┆ … ┆ 8000EBD30 ┆ 2022-09-01 ┆ 3697.34  ┆ 0         │
# │         ┆           ┆           ┆ 16:25:00   ┆   ┆           ┆ 00:20:00   ┆          ┆           │
# │ 1874382 ┆ 80C1C4030 ┆ 8000EBD30 ┆ 2022-09-03 ┆ … ┆ 8000EBD30 ┆ 2022-09-01 ┆ 3697.34  ┆ 0         │
# │         ┆           ┆           ┆ 00:04:00   ┆   ┆           ┆ 00:20:00   ┆          ┆           │
# │ …       ┆ …         ┆ …         ┆ …          ┆ … ┆ …         ┆ …          ┆ …        ┆ …         │
# │ 411414  ┆ 8148A6311 ┆ 8148A6311 ┆ 2022-09-01 ┆ … ┆ 8148A8711 ┆ 2022-09-10 ┆ 0.038417 ┆ 0         │
# │         ┆           ┆           ┆ 02:46:00   ┆   ┆           ┆ 23:46:00   ┆          ┆           │
# │ 1515967 ┆ 8148A6181 ┆ 8148A6311 ┆ 2022-09-02 ┆ … ┆ 8148A8711 ┆ 2022-09-10 ┆ 0.038417 ┆ 0         │
# │         ┆           ┆           ┆ 12:27:00   ┆   ┆           ┆ 23:46:00   ┆          ┆           │
# │ 4590253 ┆ 8148A6181 ┆ 8148A6311 ┆ 2022-09-09 ┆ … ┆ 8148A8711 ┆ 2022-09-10 ┆ 0.038417 ┆ 0         │
# │         ┆           ┆           ┆ 13:01:00   ┆   ┆           ┆ 23:46:00   ┆          ┆           │
# │ 478259  ┆ 8148A6091 ┆ 8148A6091 ┆ 2022-09-01 ┆ … ┆ 8148A8711 ┆ 2022-09-10 ┆ 0.281983 ┆ 0         │
# │         ┆           ┆           ┆ 04:36:00   ┆   ┆           ┆ 23:37:00   ┆          ┆           │
# │ 813217  ┆ 8148A6091 ┆ 8148A6091 ┆ 2022-09-01 ┆ … ┆ 8148A8711 ┆ 2022-09-10 ┆ 0.281983 ┆ 0         │
# │         ┆           ┆           ┆ 14:49:00   ┆   ┆           ┆ 23:37:00   ┆          ┆           │
# └─────────┴───────────┴───────────┴────────────┴───┴───────────┴────────────┴──────────┴───────────┘

# %%
timedelta = pl.duration(hours=24)

# %% [markdown]
# ## Filter Edges
#
# Keep only edges where the second transaction occurs within 24 hours after the first.

# %%
edges = edges.filter(
    (pl.col("t_i_d") > pl.col("t_i")) & 
    (pl.col("t_i_d") < pl.col("t_i") + timedelta)
)

# %% [markdown]
# ## Temporal View Results
#
# Display final nodes and edges.

# %%
print(nodes.collect())
# Out:
# shape: (4_597_289, 6)
# ┌─────────┬───────────┬───────────┬─────────────────────┬──────────┬───────────────┐
# │ node_id ┆ f_i       ┆ b_i       ┆ t_i                 ┆ a_i      ┆ Is Laundering │
# │ ---     ┆ ---       ┆ ---       ┆ ---                 ┆ ---      ┆ ---           │
# │ u32     ┆ str       ┆ str       ┆ datetime[μs]        ┆ f64      ┆ i64           │
# ╞═════════╪═══════════╪═══════════╪═════════════════════╪══════════╪═══════════════╡
# │ 0       ┆ 8000F4580 ┆ 8000F5340 ┆ 2022-09-01 00:20:00 ┆ 0.01     ┆ 0             │
# │ 1       ┆ 8000EC280 ┆ 8017BF800 ┆ 2022-09-01 00:26:00 ┆ 7.66     ┆ 0             │
# │ 2       ┆ 8000EDEC0 ┆ 80AEF5310 ┆ 2022-09-01 00:21:00 ┆ 383.71   ┆ 0             │
# │ 3       ┆ 8000F4510 ┆ 8011305D0 ┆ 2022-09-01 00:04:00 ┆ 9.82     ┆ 0             │
# │ 4       ┆ 8000F4FE0 ┆ 812ED62E0 ┆ 2022-09-01 00:08:00 ┆ 4.01     ┆ 0             │
# │ …       ┆ …         ┆ …         ┆ …                   ┆ …        ┆ …             │
# │ 4597284 ┆ 8148A6631 ┆ 8148A8711 ┆ 2022-09-10 23:57:00 ┆ 0.154978 ┆ 0             │
# │ 4597285 ┆ 8148A8671 ┆ 8148A8711 ┆ 2022-09-10 23:35:00 ┆ 0.108128 ┆ 0             │
# │ 4597286 ┆ 8148A6771 ┆ 8148A8711 ┆ 2022-09-10 23:52:00 ┆ 0.004988 ┆ 0             │
# │ 4597287 ┆ 8148A6311 ┆ 8148A8711 ┆ 2022-09-10 23:46:00 ┆ 0.038417 ┆ 0             │
# │ 4597288 ┆ 8148A6091 ┆ 8148A8711 ┆ 2022-09-10 23:37:00 ┆ 0.281983 ┆ 0             │
# └─────────┴───────────┴───────────┴─────────────────────┴──────────┴───────────────┘

# %%
# print(edges.select(["v_s", "v_d", "t_i", "t_i_d"]).collect())
# Out:
# shape: (34_739_332, 4)
# ┌─────────┬─────────┬─────────────────────┬─────────────────────┐
# │ v_s     ┆ v_d     ┆ t_i                 ┆ t_i_d               │
# │ ---     ┆ ---     ┆ ---                 ┆ ---                 │
# │ u32     ┆ u32     ┆ datetime[μs]        ┆ datetime[μs]        │
# ╞═════════╪═════════╪═════════════════════╪═════════════════════╡
# │ 280625  ┆ 3       ┆ 2022-09-01 00:00:00 ┆ 2022-09-01 00:02:00 │
# │ 30133   ┆ 5       ┆ 2022-09-01 00:01:00 ┆ 2022-09-01 00:03:00 │
# │ 94948   ┆ 7       ┆ 2022-09-01 00:11:00 ┆ 2022-09-01 00:16:00 │
# │ 97148   ┆ 15      ┆ 2022-09-01 00:05:00 ┆ 2022-09-01 00:09:00 │
# │ 23      ┆ 18      ┆ 2022-09-01 00:02:00 ┆ 2022-09-01 00:28:00 │
# │ …       ┆ …       ┆ …                   ┆ …                   │
# │ 5018387 ┆ 5078330 ┆ 2022-09-10 16:12:00 ┆ 2022-09-10 23:52:00 │
# │ 5018388 ┆ 5078330 ┆ 2022-09-10 16:24:00 ┆ 2022-09-10 23:52:00 │
# │ 4945754 ┆ 5078335 ┆ 2022-09-10 07:20:00 ┆ 2022-09-10 23:37:00 │
# │ 4945755 ┆ 5078335 ┆ 2022-09-10 07:07:00 ┆ 2022-09-10 23:37:00 │
# │ 5046133 ┆ 5078342 ┆ 2022-09-10 19:57:00 ┆ 2022-09-10 23:52:00 │
# └─────────┴─────────┴─────────────────────┴─────────────────────┘

# %% [markdown]
# # Second Order Graph Creation
