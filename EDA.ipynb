# %% [markdown]
# # Transaction Data Analysis
#
# This notebook analyzes transaction patterns and creates a graph structure for money laundering detection.

# %%
# !pip install polars
# !pip install networkx
# !pip install matplotlib
# !pip install igraph
# Out:
# Requirement already satisfied: polars in /opt/miniconda3/envs/homl3/lib/python3.10/site-packages (1.36.1)
# Requirement already satisfied: polars-runtime-32==1.36.1 in /opt/miniconda3/envs/homl3/lib/python3.10/site-packages (from polars) (1.36.1)
# Requirement already satisfied: networkx in /opt/miniconda3/envs/homl3/lib/python3.10/site-packages (3.4.2)
# Requirement already satisfied: matplotlib in /opt/miniconda3/envs/homl3/lib/python3.10/site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/miniconda3/envs/homl3/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda3/envs/homl3/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/envs/homl3/lib/python3.10/site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/miniconda3/envs/homl3/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.21 in /opt/miniconda3/envs/homl3/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/envs/homl3/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/miniconda3/envs/homl3/lib/python3.10/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/miniconda3/envs/homl3/lib/python3.10/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda3/envs/homl3/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/homl3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Collecting igraph
#   Downloading igraph-1.0.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (4.4 kB)
# Collecting texttable>=1.6.2 (from igraph)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Downloading igraph-1.0.0-cp39-abi3-macosx_11_0_arm64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 655.2 kB/s eta 0:00:00a 0:00:01
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [igraph]
# Successfully installed igraph-1.0.0 texttable-1.7.0

# %% [markdown]
# ## Setup
#
# Install required library.

# %%
import polars as pl
import networkx as nx
import matplotlib.pyplot as plt

# df = pl.read_csv('data/HI-Small_Trans.csv')
# Try lazy frame
df = pl.read_csv('data/HI-Small_Trans.csv')

# Sample only 10% of full data for memory management, commented out if want full data
df = df.sample(fraction=0.10, with_replacement=False, seed=42).lazy()

# %% [markdown]
# ## Load Data
#
# Read transaction data from CSV file.

# %%
df.collect()
# Out:
# shape: (507_834, 11)
# ┌────────────┬───────────┬───────────┬─────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Timestamp  ┆ From Bank ┆ Account   ┆ To Bank ┆ … ┆ Amount    ┆ Payment   ┆ Payment   ┆ Is Launde │
# │ ---        ┆ ---       ┆ ---       ┆ ---     ┆   ┆ Paid      ┆ Currency  ┆ Format    ┆ ring      │
# │ str        ┆ i64       ┆ str       ┆ i64     ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │            ┆           ┆           ┆         ┆   ┆ f64       ┆ str       ┆ str       ┆ i64       │
# ╞════════════╪═══════════╪═══════════╪═════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2022/09/08 ┆ 7         ┆ 807688770 ┆ 220504  ┆ … ┆ 504.6     ┆ UK Pound  ┆ Credit    ┆ 0         │
# │ 19:55      ┆           ┆           ┆         ┆   ┆           ┆           ┆ Card      ┆           │
# │ 2022/09/02 ┆ 10099     ┆ 803F400C0 ┆ 24      ┆ … ┆ 20835.05  ┆ Yen       ┆ Cash      ┆ 0         │
# │ 15:48      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022/09/10 ┆ 1547      ┆ 80D13CC40 ┆ 2467    ┆ … ┆ 587.72    ┆ Euro      ┆ ACH       ┆ 0         │
# │ 13:41      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022/09/07 ┆ 15747     ┆ 8118ABE40 ┆ 20226   ┆ … ┆ 20085.98  ┆ US Dollar ┆ Cheque    ┆ 0         │
# │ 15:19      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022/09/08 ┆ 126       ┆ 8136E45C1 ┆ 126     ┆ … ┆ 0.00859   ┆ Bitcoin   ┆ Bitcoin   ┆ 0         │
# │ 14:02      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ …         ┆ …         ┆ …       ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2022/09/08 ┆ 1024      ┆ 801881BF0 ┆ 410     ┆ … ┆ 125.93    ┆ Euro      ┆ ACH       ┆ 0         │
# │ 09:11      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022/09/02 ┆ 2454      ┆ 8022D39C0 ┆ 1412    ┆ … ┆ 3780.75   ┆ US Dollar ┆ ACH       ┆ 0         │
# │ 17:05      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022/09/09 ┆ 3         ┆ 800045510 ┆ 1267    ┆ … ┆ 14299.75  ┆ Yuan      ┆ Credit    ┆ 0         │
# │ 12:01      ┆           ┆           ┆         ┆   ┆           ┆           ┆ Card      ┆           │
# │ 2022/09/02 ┆ 70        ┆ 1004286A8 ┆ 218050  ┆ … ┆ 198.5     ┆ Euro      ┆ Cash      ┆ 0         │
# │ 11:15      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022/09/09 ┆ 9         ┆ 806321520 ┆ 117435  ┆ … ┆ 300054.04 ┆ Ruble     ┆ Credit    ┆ 0         │
# │ 01:05      ┆           ┆           ┆         ┆   ┆           ┆           ┆ Card      ┆           │
# └────────────┴───────────┴───────────┴─────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
df = df.with_columns(
    pl.col('Timestamp').str.strptime(pl.Datetime, format='%Y/%m/%d %H:%M')
)

# %% [markdown]
# ## Data Preparation
#
# Convert timestamp column to datetime format.

# %%
df.collect()
# Out:
# shape: (507_834, 11)
# ┌────────────┬───────────┬───────────┬─────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Timestamp  ┆ From Bank ┆ Account   ┆ To Bank ┆ … ┆ Amount    ┆ Payment   ┆ Payment   ┆ Is Launde │
# │ ---        ┆ ---       ┆ ---       ┆ ---     ┆   ┆ Paid      ┆ Currency  ┆ Format    ┆ ring      │
# │ datetime[μ ┆ i64       ┆ str       ┆ i64     ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ s]         ┆           ┆           ┆         ┆   ┆ f64       ┆ str       ┆ str       ┆ i64       │
# ╞════════════╪═══════════╪═══════════╪═════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2022-09-08 ┆ 7         ┆ 807688770 ┆ 220504  ┆ … ┆ 504.6     ┆ UK Pound  ┆ Credit    ┆ 0         │
# │ 19:55:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆ Card      ┆           │
# │ 2022-09-02 ┆ 10099     ┆ 803F400C0 ┆ 24      ┆ … ┆ 20835.05  ┆ Yen       ┆ Cash      ┆ 0         │
# │ 15:48:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022-09-10 ┆ 1547      ┆ 80D13CC40 ┆ 2467    ┆ … ┆ 587.72    ┆ Euro      ┆ ACH       ┆ 0         │
# │ 13:41:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022-09-07 ┆ 15747     ┆ 8118ABE40 ┆ 20226   ┆ … ┆ 20085.98  ┆ US Dollar ┆ Cheque    ┆ 0         │
# │ 15:19:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022-09-08 ┆ 126       ┆ 8136E45C1 ┆ 126     ┆ … ┆ 0.00859   ┆ Bitcoin   ┆ Bitcoin   ┆ 0         │
# │ 14:02:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ …         ┆ …         ┆ …       ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2022-09-08 ┆ 1024      ┆ 801881BF0 ┆ 410     ┆ … ┆ 125.93    ┆ Euro      ┆ ACH       ┆ 0         │
# │ 09:11:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022-09-02 ┆ 2454      ┆ 8022D39C0 ┆ 1412    ┆ … ┆ 3780.75   ┆ US Dollar ┆ ACH       ┆ 0         │
# │ 17:05:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022-09-09 ┆ 3         ┆ 800045510 ┆ 1267    ┆ … ┆ 14299.75  ┆ Yuan      ┆ Credit    ┆ 0         │
# │ 12:01:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆ Card      ┆           │
# │ 2022-09-02 ┆ 70        ┆ 1004286A8 ┆ 218050  ┆ … ┆ 198.5     ┆ Euro      ┆ Cash      ┆ 0         │
# │ 11:15:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022-09-09 ┆ 9         ┆ 806321520 ┆ 117435  ┆ … ┆ 300054.04 ┆ Ruble     ┆ Credit    ┆ 0         │
# │ 01:05:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆ Card      ┆           │
# └────────────┴───────────┴───────────┴─────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# Disregard transaction with Payment Format "Reinvesment"

# %%
df = df.filter(pl.col("Payment Format") != "Reinvestment")

# %% [markdown]
# ## Create Nodes
#
# Build graph nodes from transactions with ID, sender, receiver, time, amount, and label.

# %%
nodes = df.with_row_index("node_id").select([
    pl.col("node_id"),
    pl.col("Account").alias("f_i"),                # From
    pl.col("Account_duplicated_0").alias("b_i"),   # Beneficiary
    pl.col("Timestamp").alias("t_i"),              # Time
    pl.col("Amount Received").alias("a_i"),        # Amount
    pl.col("Is Laundering")                        # Ground truth
])

# %%
nodes.collect()
# Out:
# shape: (459_551, 6)
# ┌─────────┬───────────┬───────────┬─────────────────────┬───────────┬───────────────┐
# │ node_id ┆ f_i       ┆ b_i       ┆ t_i                 ┆ a_i       ┆ Is Laundering │
# │ ---     ┆ ---       ┆ ---       ┆ ---                 ┆ ---       ┆ ---           │
# │ u32     ┆ str       ┆ str       ┆ datetime[μs]        ┆ f64       ┆ i64           │
# ╞═════════╪═══════════╪═══════════╪═════════════════════╪═══════════╪═══════════════╡
# │ 0       ┆ 807688770 ┆ 807E0A9A0 ┆ 2022-09-08 19:55:00 ┆ 504.6     ┆ 0             │
# │ 1       ┆ 803F400C0 ┆ 803FBE550 ┆ 2022-09-02 15:48:00 ┆ 20835.05  ┆ 0             │
# │ 2       ┆ 80D13CC40 ┆ 80D4D5A50 ┆ 2022-09-10 13:41:00 ┆ 587.72    ┆ 0             │
# │ 3       ┆ 8118ABE40 ┆ 8130A3320 ┆ 2022-09-07 15:19:00 ┆ 20085.98  ┆ 0             │
# │ 4       ┆ 8136E45C1 ┆ 813F46D51 ┆ 2022-09-08 14:02:00 ┆ 0.00859   ┆ 0             │
# │ …       ┆ …         ┆ …         ┆ …                   ┆ …         ┆ …             │
# │ 459546  ┆ 801881BF0 ┆ 8028D2D60 ┆ 2022-09-08 09:11:00 ┆ 125.93    ┆ 0             │
# │ 459547  ┆ 8022D39C0 ┆ 802EE4B70 ┆ 2022-09-02 17:05:00 ┆ 3780.75   ┆ 0             │
# │ 459548  ┆ 800045510 ┆ 8007C73D0 ┆ 2022-09-09 12:01:00 ┆ 14299.75  ┆ 0             │
# │ 459549  ┆ 1004286A8 ┆ 80831D6F0 ┆ 2022-09-02 11:15:00 ┆ 198.5     ┆ 0             │
# │ 459550  ┆ 806321520 ┆ 806B2E830 ┆ 2022-09-09 01:05:00 ┆ 300054.04 ┆ 0             │
# └─────────┴───────────┴───────────┴─────────────────────┴───────────┴───────────────┘

# %% [markdown]
# ## Create Edges
#
# Connect transactions where one receiver becomes the sender in another transaction.

# %%
edges = nodes.join(
    nodes,
    left_on="b_i", 
    right_on="f_i",
    suffix="_d"
).rename({"node_id": "v_s", "node_id_d": "v_d"})

# %%
edges.collect()
# Out:
# shape: (3_408_676, 11)
# ┌────────┬───────────┬───────────┬────────────┬───┬───────────┬────────────┬───────────┬───────────┐
# │ v_s    ┆ f_i       ┆ b_i       ┆ t_i        ┆ … ┆ b_i_d     ┆ t_i_d      ┆ a_i_d     ┆ Is Launde │
# │ ---    ┆ ---       ┆ ---       ┆ ---        ┆   ┆ ---       ┆ ---        ┆ ---       ┆ ring_d    │
# │ u32    ┆ str       ┆ str       ┆ datetime[μ ┆   ┆ str       ┆ datetime[μ ┆ f64       ┆ ---       │
# │        ┆           ┆           ┆ s]         ┆   ┆           ┆ s]         ┆           ┆ i64       │
# ╞════════╪═══════════╪═══════════╪════════════╪═══╪═══════════╪════════════╪═══════════╪═══════════╡
# │ 109860 ┆ 8000955D0 ┆ 807688770 ┆ 2022-09-08 ┆ … ┆ 807E0A9A0 ┆ 2022-09-08 ┆ 504.6     ┆ 0         │
# │        ┆           ┆           ┆ 17:26:00   ┆   ┆           ┆ 19:55:00   ┆           ┆           │
# │ 86445  ┆ 803A621E0 ┆ 803F400C0 ┆ 2022-09-06 ┆ … ┆ 803FBE550 ┆ 2022-09-02 ┆ 20835.05  ┆ 0         │
# │        ┆           ┆           ┆ 07:10:00   ┆   ┆           ┆ 15:48:00   ┆           ┆           │
# │ 67016  ┆ 80D074610 ┆ 80D13CC40 ┆ 2022-09-05 ┆ … ┆ 80D4D5A50 ┆ 2022-09-10 ┆ 587.72    ┆ 0         │
# │        ┆           ┆           ┆ 04:13:00   ┆   ┆           ┆ 13:41:00   ┆           ┆           │
# │ 352111 ┆ 8043486F0 ┆ 80D13CC40 ┆ 2022-09-08 ┆ … ┆ 80D4D5A50 ┆ 2022-09-10 ┆ 587.72    ┆ 0         │
# │        ┆           ┆           ┆ 07:21:00   ┆   ┆           ┆ 13:41:00   ┆           ┆           │
# │ 361152 ┆ 8043486F0 ┆ 80D13CC40 ┆ 2022-09-05 ┆ … ┆ 80D4D5A50 ┆ 2022-09-10 ┆ 587.72    ┆ 0         │
# │        ┆           ┆           ┆ 05:25:00   ┆   ┆           ┆ 13:41:00   ┆           ┆           │
# │ …      ┆ …         ┆ …         ┆ …          ┆ … ┆ …         ┆ …          ┆ …         ┆ …         │
# │ 446930 ┆ 812123D20 ┆ 1004286A8 ┆ 2022-09-02 ┆ … ┆ 80831D6F0 ┆ 2022-09-02 ┆ 198.5     ┆ 0         │
# │        ┆           ┆           ┆ 23:21:00   ┆   ┆           ┆ 11:15:00   ┆           ┆           │
# │ 454187 ┆ 804206B40 ┆ 1004286A8 ┆ 2022-09-02 ┆ … ┆ 80831D6F0 ┆ 2022-09-02 ┆ 198.5     ┆ 0         │
# │        ┆           ┆           ┆ 08:08:00   ┆   ┆           ┆ 11:15:00   ┆           ┆           │
# │ 458099 ┆ 80AC1D6F0 ┆ 1004286A8 ┆ 2022-09-09 ┆ … ┆ 80831D6F0 ┆ 2022-09-02 ┆ 198.5     ┆ 0         │
# │        ┆           ┆           ┆ 00:59:00   ┆   ┆           ┆ 11:15:00   ┆           ┆           │
# │ 192530 ┆ 8061E8E30 ┆ 806321520 ┆ 2022-09-08 ┆ … ┆ 806B2E830 ┆ 2022-09-09 ┆ 300054.04 ┆ 0         │
# │        ┆           ┆           ┆ 19:01:00   ┆   ┆           ┆ 01:05:00   ┆           ┆           │
# │ 298566 ┆ 8061E8E30 ┆ 806321520 ┆ 2022-09-02 ┆ … ┆ 806B2E830 ┆ 2022-09-09 ┆ 300054.04 ┆ 0         │
# │        ┆           ┆           ┆ 14:50:00   ┆   ┆           ┆ 01:05:00   ┆           ┆           │
# └────────┴───────────┴───────────┴────────────┴───┴───────────┴────────────┴───────────┴───────────┘

# %% [markdown]
# ## Time Delta Window

# %%
timedelta = pl.duration(hours=24)

# %% [markdown]
# ## Filter Edges
#
# Keep only edges where the second transaction occurs within 24 hours after the first.

# %%
edges = edges.filter(
    (pl.col("t_i_d") > pl.col("t_i")) & 
    (pl.col("t_i_d") < pl.col("t_i") + timedelta)
)

# %% [markdown]
# ## Temporal View Results
#
# Display final nodes and edges.

# %%
print(nodes.collect())
# Out:
# shape: (459_551, 6)
# ┌─────────┬───────────┬───────────┬─────────────────────┬───────────┬───────────────┐
# │ node_id ┆ f_i       ┆ b_i       ┆ t_i                 ┆ a_i       ┆ Is Laundering │
# │ ---     ┆ ---       ┆ ---       ┆ ---                 ┆ ---       ┆ ---           │
# │ u32     ┆ str       ┆ str       ┆ datetime[μs]        ┆ f64       ┆ i64           │
# ╞═════════╪═══════════╪═══════════╪═════════════════════╪═══════════╪═══════════════╡
# │ 0       ┆ 807688770 ┆ 807E0A9A0 ┆ 2022-09-08 19:55:00 ┆ 504.6     ┆ 0             │
# │ 1       ┆ 803F400C0 ┆ 803FBE550 ┆ 2022-09-02 15:48:00 ┆ 20835.05  ┆ 0             │
# │ 2       ┆ 80D13CC40 ┆ 80D4D5A50 ┆ 2022-09-10 13:41:00 ┆ 587.72    ┆ 0             │
# │ 3       ┆ 8118ABE40 ┆ 8130A3320 ┆ 2022-09-07 15:19:00 ┆ 20085.98  ┆ 0             │
# │ 4       ┆ 8136E45C1 ┆ 813F46D51 ┆ 2022-09-08 14:02:00 ┆ 0.00859   ┆ 0             │
# │ …       ┆ …         ┆ …         ┆ …                   ┆ …         ┆ …             │
# │ 459546  ┆ 801881BF0 ┆ 8028D2D60 ┆ 2022-09-08 09:11:00 ┆ 125.93    ┆ 0             │
# │ 459547  ┆ 8022D39C0 ┆ 802EE4B70 ┆ 2022-09-02 17:05:00 ┆ 3780.75   ┆ 0             │
# │ 459548  ┆ 800045510 ┆ 8007C73D0 ┆ 2022-09-09 12:01:00 ┆ 14299.75  ┆ 0             │
# │ 459549  ┆ 1004286A8 ┆ 80831D6F0 ┆ 2022-09-02 11:15:00 ┆ 198.5     ┆ 0             │
# │ 459550  ┆ 806321520 ┆ 806B2E830 ┆ 2022-09-09 01:05:00 ┆ 300054.04 ┆ 0             │
# └─────────┴───────────┴───────────┴─────────────────────┴───────────┴───────────────┘

# %% [markdown]
# ## Second Order Graph Creation

# %% [markdown]
# ### Edge creation

# %%
s_edges = edges.with_columns([
    pl.concat_str([pl.col("f_i"), pl.col("b_i")], separator="->").alias("v_s"),
    pl.concat_str([pl.col("b_i"), pl.col("b_i_d")], separator="->").alias("v_d")
]).select(["v_s", "v_d"])

# %%
s_edges.collect().head()
# Out:
# shape: (5, 2)
# ┌──────────────────────┬──────────────────────┐
# │ v_s                  ┆ v_d                  │
# │ ---                  ┆ ---                  │
# │ str                  ┆ str                  │
# ╞══════════════════════╪══════════════════════╡
# │ 8000955D0->807688770 ┆ 807688770->807E0A9A0 │
# │ 807AD7960->807AD6AA0 ┆ 807AD6AA0->8086A3C50 │
# │ 8076DEBB0->807C29950 ┆ 807C29950->807D5A090 │
# │ 810592760->810A3B4A0 ┆ 810A3B4A0->811357C40 │
# │ 800089CB0->80609DC20 ┆ 80609DC20->8060DB870 │
# └──────────────────────┴──────────────────────┘

# %% [markdown]
# ### Weight Calculation

# %%
# Count times where one node goes to another
s_edges_with_count = s_edges.group_by(["v_s", "v_d"]).agg([
    pl.len().alias("spec_count")
])

denom_P = s_edges.group_by("v_s").agg([
    pl.len().alias("s_to_any")
])

denom_P_prime = s_edges.group_by("v_d").agg([
    pl.len().alias("any_to_d")
])

# %%
print(s_edges_with_count.collect().head())

print(denom_P.collect().head())

print(denom_P_prime.collect().head())
# Out:
# shape: (5, 3)
# ┌──────────────────────┬──────────────────────┬────────────┐
# │ v_s                  ┆ v_d                  ┆ spec_count │
# │ ---                  ┆ ---                  ┆ ---        │
# │ str                  ┆ str                  ┆ u32        │
# ╞══════════════════════╪══════════════════════╪════════════╡
# │ 80C17A100->80C5CEF80 ┆ 80C5CEF80->80CA65B80 ┆ 1          │
# │ 802949240->8027987E0 ┆ 8027987E0->80BAFB1F0 ┆ 1          │
# │ 80061AF50->80061AF50 ┆ 80061AF50->80BE56630 ┆ 1          │
# │ 801465E70->100428660 ┆ 100428660->80E6B56F0 ┆ 1          │
# │ 80D229080->100428660 ┆ 100428660->810E7D6A0 ┆ 1          │
# └──────────────────────┴──────────────────────┴────────────┘
# shape: (5, 2)
# ┌──────────────────────┬──────────┐
# │ v_s                  ┆ s_to_any │
# │ ---                  ┆ ---      │
# │ str                  ┆ u32      │
# ╞══════════════════════╪══════════╡
# │ 801E016D0->801E18890 ┆ 1        │
# │ 80EDE2570->80F437C50 ┆ 2        │
# │ 80266DB40->80326CDA0 ┆ 1        │
# │ 80FE1DB40->80FD75D80 ┆ 1        │
# │ 802AE35E0->80B8D9C00 ┆ 2        │
# └──────────────────────┴──────────┘
# shape: (5, 2)
# ┌──────────────────────┬──────────┐
# │ v_d                  ┆ any_to_d │
# │ ---                  ┆ ---      │
# │ str                  ┆ u32      │
# ╞══════════════════════╪══════════╡
# │ 100428660->80A82FE40 ┆ 13       │
# │ 800279000->8002AA400 ┆ 1        │
# │ 8002F0720->80092D790 ┆ 2        │
# │ 800EBFCB0->80433D470 ┆ 1        │
# │ 80670CF40->80C50AB40 ┆ 1        │
# └──────────────────────┴──────────┘

# %%
s_edges_with_weight = s_edges_with_count.join(
    denom_P,
    on="v_s",
    how="left"
).join(
    denom_P_prime,
    on="v_d",
    how="left"
).with_columns([
    (pl.col("spec_count") / pl.col("s_to_any")).alias("P"),
    (pl.col("spec_count") / pl.col("any_to_d")).alias("P_prime")
]).with_columns([
    (pl.max_horizontal([pl.col("P"), pl.col("P_prime")])).alias("weight")
])

# %%
print(s_edges_with_weight.collect().head())
# Out:
# shape: (5, 8)
# ┌───────────────┬──────────────┬────────────┬──────────┬──────────┬──────────┬──────────┬──────────┐
# │ v_s           ┆ v_d          ┆ spec_count ┆ s_to_any ┆ any_to_d ┆ P        ┆ P_prime  ┆ weight   │
# │ ---           ┆ ---          ┆ ---        ┆ ---      ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ str           ┆ str          ┆ u32        ┆ u32      ┆ u32      ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════════════╪══════════════╪════════════╪══════════╪══════════╪══════════╪══════════╪══════════╡
# │ 80BE26900->10 ┆ 100428660->8 ┆ 1          ┆ 748      ┆ 38       ┆ 0.001337 ┆ 0.026316 ┆ 0.026316 │
# │ 0428660       ┆ 0A71A250     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 8082338C0->10 ┆ 100428660->8 ┆ 1          ┆ 974      ┆ 53       ┆ 0.001027 ┆ 0.018868 ┆ 0.018868 │
# │ 0428660       ┆ 0161A8D0     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 80352F5A0->10 ┆ 100428660->8 ┆ 1          ┆ 2145     ┆ 84       ┆ 0.000466 ┆ 0.011905 ┆ 0.011905 │
# │ 0428660       ┆ 10438E20     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 808FB2B60->10 ┆ 100428660->8 ┆ 1          ┆ 1449     ┆ 43       ┆ 0.00069  ┆ 0.023256 ┆ 0.023256 │
# │ 0428660       ┆ 09F18010     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 803462A00->80 ┆ 8058902B0->8 ┆ 2          ┆ 2        ┆ 4        ┆ 1.0      ┆ 0.5      ┆ 1.0      │
# │ 58902B0       ┆ 122D4A40     ┆            ┆          ┆          ┆          ┆          ┆          │
# └───────────────┴──────────────┴────────────┴──────────┴──────────┴──────────┴──────────┴──────────┘

# %% [markdown]
# ### Apply second order graph's weight to Temporal graph's edges

# %%
edges_with_weight = edges.with_columns([
    pl.concat_str([pl.col("f_i"), pl.col("b_i")], separator="->").alias("tx_s"),
    pl.concat_str([pl.col("b_i"), pl.col("b_i_d")], separator="->").alias("tx_d")
]).join(
    s_edges_with_weight.select([
        "v_s", "v_d", "weight"
    ]),
    left_on=["tx_s", "tx_d"],
    right_on=["v_s", "v_d"],
    how="left"
).drop([
    "tx_s", "tx_d", "v_s", "v_d"
])

# %%
edges_with_weight.collect().filter(pl.col("Is Laundering") == 1)
# Out:
# shape: (101, 10)
# ┌───────────┬───────────┬────────────┬──────────┬───┬────────────┬───────────┬────────────┬────────┐
# │ f_i       ┆ b_i       ┆ t_i        ┆ a_i      ┆ … ┆ t_i_d      ┆ a_i_d     ┆ Is Launder ┆ weight │
# │ ---       ┆ ---       ┆ ---        ┆ ---      ┆   ┆ ---        ┆ ---       ┆ ing_d      ┆ ---    │
# │ str       ┆ str       ┆ datetime[μ ┆ f64      ┆   ┆ datetime[μ ┆ f64       ┆ ---        ┆ f64    │
# │           ┆           ┆ s]         ┆          ┆   ┆ s]         ┆           ┆ i64        ┆        │
# ╞═══════════╪═══════════╪════════════╪══════════╪═══╪════════════╪═══════════╪════════════╪════════╡
# │ 8119F8CC0 ┆ 80B0C3F40 ┆ 2022-09-11 ┆ 8019.98  ┆ … ┆ 2022-09-12 ┆ 20956.02  ┆ 0          ┆ 1.0    │
# │           ┆           ┆ 14:02:00   ┆          ┆   ┆ 10:34:00   ┆           ┆            ┆        │
# │ 8014E85C0 ┆ 8007C82A0 ┆ 2022-09-03 ┆ 3169.29  ┆ … ┆ 2022-09-04 ┆ 777331.33 ┆ 0          ┆ 1.0    │
# │           ┆           ┆ 19:10:00   ┆          ┆   ┆ 11:13:00   ┆           ┆            ┆        │
# │ 80BE87020 ┆ 8013F0350 ┆ 2022-09-07 ┆ 5472.94  ┆ … ┆ 2022-09-08 ┆ 147.31    ┆ 0          ┆ 1.0    │
# │           ┆           ┆ 22:10:00   ┆          ┆   ┆ 12:40:00   ┆           ┆            ┆        │
# │ 804093380 ┆ 811B90FA0 ┆ 2022-09-12 ┆ 14732.08 ┆ … ┆ 2022-09-13 ┆ 13835.02  ┆ 0          ┆ 1.0    │
# │           ┆           ┆ 18:10:00   ┆          ┆   ┆ 12:05:00   ┆           ┆            ┆        │
# │ 806E1B6F0 ┆ 8013F0350 ┆ 2022-09-07 ┆ 1456.96  ┆ … ┆ 2022-09-07 ┆ 147.31    ┆ 0          ┆ 1.0    │
# │           ┆           ┆ 11:22:00   ┆          ┆   ┆ 14:54:00   ┆           ┆            ┆        │
# │ …         ┆ …         ┆ …          ┆ …        ┆ … ┆ …          ┆ …         ┆ …          ┆ …      │
# │ 811D80C30 ┆ 811A65E30 ┆ 2022-09-07 ┆ 26259.53 ┆ … ┆ 2022-09-07 ┆ 1180.16   ┆ 0          ┆ 1.0    │
# │           ┆           ┆ 05:00:00   ┆          ┆   ┆ 15:14:00   ┆           ┆            ┆        │
# │ 8001B2240 ┆ 80017C540 ┆ 2022-09-07 ┆ 12959.17 ┆ … ┆ 2022-09-08 ┆ 202.96    ┆ 0          ┆ 0.5    │
# │           ┆           ┆ 18:18:00   ┆          ┆   ┆ 02:05:00   ┆           ┆            ┆        │
# │ 80693AB90 ┆ 800049680 ┆ 2022-09-05 ┆ 11625.36 ┆ … ┆ 2022-09-05 ┆ 414.02    ┆ 0          ┆ 1.0    │
# │           ┆           ┆ 07:38:00   ┆          ┆   ┆ 10:06:00   ┆           ┆            ┆        │
# │ 100428660 ┆ 8005FF6D0 ┆ 2022-09-09 ┆ 16279.09 ┆ … ┆ 2022-09-09 ┆ 6678.11   ┆ 0          ┆ 1.0    │
# │           ┆           ┆ 03:50:00   ┆          ┆   ┆ 09:26:00   ┆           ┆            ┆        │
# │ 8017C71A0 ┆ 8017C7330 ┆ 2022-09-06 ┆ 2798.64  ┆ … ┆ 2022-09-06 ┆ 9246.08   ┆ 0          ┆ 1.0    │
# │           ┆           ┆ 07:09:00   ┆          ┆   ┆ 23:32:00   ┆           ┆            ┆        │
# └───────────┴───────────┴────────────┴──────────┴───┴────────────┴───────────┴────────────┴────────┘

# %%
edges_with_weight.collect().filter(pl.col("Is Laundering") == 1)
# Out:
# shape: (101, 10)
# ┌───────────┬───────────┬────────────┬──────────┬───┬────────────┬───────────┬────────────┬────────┐
# │ f_i       ┆ b_i       ┆ t_i        ┆ a_i      ┆ … ┆ t_i_d      ┆ a_i_d     ┆ Is Launder ┆ weight │
# │ ---       ┆ ---       ┆ ---        ┆ ---      ┆   ┆ ---        ┆ ---       ┆ ing_d      ┆ ---    │
# │ str       ┆ str       ┆ datetime[μ ┆ f64      ┆   ┆ datetime[μ ┆ f64       ┆ ---        ┆ f64    │
# │           ┆           ┆ s]         ┆          ┆   ┆ s]         ┆           ┆ i64        ┆        │
# ╞═══════════╪═══════════╪════════════╪══════════╪═══╪════════════╪═══════════╪════════════╪════════╡
# │ 8119F8CC0 ┆ 80B0C3F40 ┆ 2022-09-11 ┆ 8019.98  ┆ … ┆ 2022-09-12 ┆ 20956.02  ┆ 0          ┆ 1.0    │
# │           ┆           ┆ 14:02:00   ┆          ┆   ┆ 10:34:00   ┆           ┆            ┆        │
# │ 8014E85C0 ┆ 8007C82A0 ┆ 2022-09-03 ┆ 3169.29  ┆ … ┆ 2022-09-04 ┆ 777331.33 ┆ 0          ┆ 1.0    │
# │           ┆           ┆ 19:10:00   ┆          ┆   ┆ 11:13:00   ┆           ┆            ┆        │
# │ 80BE87020 ┆ 8013F0350 ┆ 2022-09-07 ┆ 5472.94  ┆ … ┆ 2022-09-08 ┆ 147.31    ┆ 0          ┆ 1.0    │
# │           ┆           ┆ 22:10:00   ┆          ┆   ┆ 12:40:00   ┆           ┆            ┆        │
# │ 804093380 ┆ 811B90FA0 ┆ 2022-09-12 ┆ 14732.08 ┆ … ┆ 2022-09-13 ┆ 13835.02  ┆ 0          ┆ 1.0    │
# │           ┆           ┆ 18:10:00   ┆          ┆   ┆ 12:05:00   ┆           ┆            ┆        │
# │ 806E1B6F0 ┆ 8013F0350 ┆ 2022-09-07 ┆ 1456.96  ┆ … ┆ 2022-09-07 ┆ 147.31    ┆ 0          ┆ 1.0    │
# │           ┆           ┆ 11:22:00   ┆          ┆   ┆ 14:54:00   ┆           ┆            ┆        │
# │ …         ┆ …         ┆ …          ┆ …        ┆ … ┆ …          ┆ …         ┆ …          ┆ …      │
# │ 811D80C30 ┆ 811A65E30 ┆ 2022-09-07 ┆ 26259.53 ┆ … ┆ 2022-09-07 ┆ 1180.16   ┆ 0          ┆ 1.0    │
# │           ┆           ┆ 05:00:00   ┆          ┆   ┆ 15:14:00   ┆           ┆            ┆        │
# │ 8001B2240 ┆ 80017C540 ┆ 2022-09-07 ┆ 12959.17 ┆ … ┆ 2022-09-08 ┆ 202.96    ┆ 0          ┆ 0.5    │
# │           ┆           ┆ 18:18:00   ┆          ┆   ┆ 02:05:00   ┆           ┆            ┆        │
# │ 80693AB90 ┆ 800049680 ┆ 2022-09-05 ┆ 11625.36 ┆ … ┆ 2022-09-05 ┆ 414.02    ┆ 0          ┆ 1.0    │
# │           ┆           ┆ 07:38:00   ┆          ┆   ┆ 10:06:00   ┆           ┆            ┆        │
# │ 100428660 ┆ 8005FF6D0 ┆ 2022-09-09 ┆ 16279.09 ┆ … ┆ 2022-09-09 ┆ 6678.11   ┆ 0          ┆ 1.0    │
# │           ┆           ┆ 03:50:00   ┆          ┆   ┆ 09:26:00   ┆           ┆            ┆        │
# │ 8017C71A0 ┆ 8017C7330 ┆ 2022-09-06 ┆ 2798.64  ┆ … ┆ 2022-09-06 ┆ 9246.08   ┆ 0          ┆ 1.0    │
# │           ┆           ┆ 07:09:00   ┆          ┆   ┆ 23:32:00   ┆           ┆            ┆        │
# └───────────┴───────────┴────────────┴──────────┴───┴────────────┴───────────┴────────────┴────────┘

# %%
edges_with_weight.collect().filter(pl.col("Is Laundering") == 1)["weight"].value_counts().sort("weight")
# Out:
# shape: (5, 2)
# ┌──────────┬───────┐
# │ weight   ┆ count │
# │ ---      ┆ ---   │
# │ f64      ┆ u32   │
# ╞══════════╪═══════╡
# │ 0.25     ┆ 1     │
# │ 0.333333 ┆ 1     │
# │ 0.5      ┆ 6     │
# │ 0.666667 ┆ 2     │
# │ 1.0      ┆ 91    │
# └──────────┴───────┘

# %%
edges_with_weight.collect().filter(pl.col("Is Laundering") == 0)["weight"].value_counts().sort("weight")
# Out:
# shape: (307, 2)
# ┌──────────┬───────┐
# │ weight   ┆ count │
# │ ---      ┆ ---   │
# │ f64      ┆ u32   │
# ╞══════════╪═══════╡
# │ 0.004878 ┆ 32    │
# │ 0.00495  ┆ 4     │
# │ 0.005236 ┆ 1     │
# │ 0.005263 ┆ 16    │
# │ 0.00578  ┆ 48    │
# │ …        ┆ …     │
# │ 0.846154 ┆ 11    │
# │ 0.857143 ┆ 72    │
# │ 0.875    ┆ 21    │
# │ 0.888889 ┆ 24    │
# │ 1.0      ┆ 71743 │
# └──────────┴───────┘

# %%
df_for_leiden = edges_with_weight.select([
    pl.concat_str(["f_i", "b_i", "t_i"]).alias("source_node"),
    pl.concat_str(["b_i", "b_i_d", "t_i_d"]).alias("target_node"),
    pl.col("weight")
])

# %%
df_for_leiden.collect()
# Out:
# shape: (333_010, 3)
# ┌─────────────────────────────────┬─────────────────────────────────┬──────────┐
# │ source_node                     ┆ target_node                     ┆ weight   │
# │ ---                             ┆ ---                             ┆ ---      │
# │ str                             ┆ str                             ┆ f64      │
# ╞═════════════════════════════════╪═════════════════════════════════╪══════════╡
# │ 8000955D08076887702022-09-08 1… ┆ 807688770807E0A9A02022-09-08 1… ┆ 1.0      │
# │ 807AD7960807AD6AA02022-09-09 1… ┆ 807AD6AA08086A3C502022-09-09 1… ┆ 1.0      │
# │ 8076DEBB0807C299502022-09-03 1… ┆ 807C29950807D5A0902022-09-03 2… ┆ 0.5      │
# │ 810592760810A3B4A02022-09-05 1… ┆ 810A3B4A0811357C402022-09-06 0… ┆ 1.0      │
# │ 800089CB080609DC202022-09-01 0… ┆ 80609DC208060DB8702022-09-01 1… ┆ 1.0      │
# │ …                               ┆ …                               ┆ …        │
# │ 802849B901004286A82022-09-02 0… ┆ 1004286A880831D6F02022-09-02 1… ┆ 0.027778 │
# │ 8134D5C801004286A82022-09-02 0… ┆ 1004286A880831D6F02022-09-02 1… ┆ 0.027778 │
# │ 80C523AF01004286A82022-09-02 0… ┆ 1004286A880831D6F02022-09-02 1… ┆ 0.027778 │
# │ 804206B401004286A82022-09-02 0… ┆ 1004286A880831D6F02022-09-02 1… ┆ 0.027778 │
# │ 8061E8E308063215202022-09-08 1… ┆ 806321520806B2E8302022-09-09 0… ┆ 1.0      │
# └─────────────────────────────────┴─────────────────────────────────┴──────────┘

# %%
df_for_leiden_with_weight_filtered = df_for_leiden.filter(pl.col("weight") >= 0.5)

# %%
df_for_leiden_with_weight_filtered.collect()
# Out:
# shape: (81_378, 3)
# ┌─────────────────────────────────┬─────────────────────────────────┬────────┐
# │ source_node                     ┆ target_node                     ┆ weight │
# │ ---                             ┆ ---                             ┆ ---    │
# │ str                             ┆ str                             ┆ f64    │
# ╞═════════════════════════════════╪═════════════════════════════════╪════════╡
# │ 8000955D08076887702022-09-08 1… ┆ 807688770807E0A9A02022-09-08 1… ┆ 1.0    │
# │ 807AD7960807AD6AA02022-09-09 1… ┆ 807AD6AA08086A3C502022-09-09 1… ┆ 1.0    │
# │ 8076DEBB0807C299502022-09-03 1… ┆ 807C29950807D5A0902022-09-03 2… ┆ 0.5    │
# │ 810592760810A3B4A02022-09-05 1… ┆ 810A3B4A0811357C402022-09-06 0… ┆ 1.0    │
# │ 800089CB080609DC202022-09-01 0… ┆ 80609DC208060DB8702022-09-01 1… ┆ 1.0    │
# │ …                               ┆ …                               ┆ …      │
# │ 8077CA2A08063DECB02022-09-05 2… ┆ 8063DECB0809CDBAC02022-09-06 1… ┆ 1.0    │
# │ 801EC5060801EE4A002022-09-09 0… ┆ 801EE4A00810A99EB02022-09-09 1… ┆ 1.0    │
# │ 805B92690806D0D5802022-09-02 0… ┆ 806D0D58080FDEB8002022-09-02 1… ┆ 1.0    │
# │ 80DCF5030801881BF02022-09-08 0… ┆ 801881BF08028D2D602022-09-08 0… ┆ 0.5    │
# │ 8061E8E308063215202022-09-08 1… ┆ 806321520806B2E8302022-09-09 0… ┆ 1.0    │
# └─────────────────────────────────┴─────────────────────────────────┴────────┘

# %%
import igraph as ig

# %%
edges_data = df_for_leiden_with_weight_filtered.select([
    "source_node", "target_node", "weight"
]).collect().to_numpy()

# %%
g = ig.Graph.TupleList(edges_data, directed=True, weights=True)

# %%
partition = g.community_leiden(weights='weight', objective_function='modularity')

# %%
partition

# %%
# Create a mapping of Transaction ID -> Community ID
node_names = g.vs["name"]
community_ids = partition.membership

community_df = pl.DataFrame({
    "node_id_str": node_names,
    "community_id": community_ids
})

# Now you can join this back to your original transaction data to see the "Fraud Rings"

# %%
community_df
# Out:
# shape: (118_678, 2)
# ┌─────────────────────────────────┬──────────────┐
# │ node_id_str                     ┆ community_id │
# │ ---                             ┆ ---          │
# │ str                             ┆ i64          │
# ╞═════════════════════════════════╪══════════════╡
# │ 8000955D08076887702022-09-08 1… ┆ 0            │
# │ 807688770807E0A9A02022-09-08 1… ┆ 0            │
# │ 807AD7960807AD6AA02022-09-09 1… ┆ 1            │
# │ 807AD6AA08086A3C502022-09-09 1… ┆ 1            │
# │ 8076DEBB0807C299502022-09-03 1… ┆ 2            │
# │ …                               ┆ …            │
# │ 8077CA2A08063DECB02022-09-05 2… ┆ 42017        │
# │ 801EE4A00810A99EB02022-09-09 1… ┆ 19061        │
# │ 805B92690806D0D5802022-09-02 0… ┆ 42018        │
# │ 806D0D58080FDEB8002022-09-02 1… ┆ 42018        │
# │ 801881BF08028D2D602022-09-08 0… ┆ 28660        │
# └─────────────────────────────────┴──────────────┘
