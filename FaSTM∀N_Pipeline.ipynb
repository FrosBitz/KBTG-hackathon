# %% [markdown]
# # Transaction Data Analysis
#
# This notebook analyzes transaction patterns and creates a graph structure for money laundering detection with FaSTM∀N Framework.

# %%
# !pip install polars
# !pip install networkx
# !pip install matplotlib
# !pip install igraph
# Out:
# Requirement already satisfied: polars in c:\users\dell\appdata\roaming\python\python313\site-packages (1.30.0)
# Requirement already satisfied: networkx in c:\users\dell\appdata\roaming\python\python313\site-packages (3.5)
# Requirement already satisfied: matplotlib in c:\users\dell\anaconda3\envs\cryptography\lib\site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\anaconda3\envs\cryptography\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\anaconda3\envs\cryptography\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\anaconda3\envs\cryptography\lib\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\anaconda3\envs\cryptography\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\dell\appdata\roaming\python\python313\site-packages (from matplotlib) (2.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\dell\appdata\roaming\python\python313\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\anaconda3\envs\cryptography\lib\site-packages (from matplotlib) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: igraph in c:\users\dell\anaconda3\envs\cryptography\lib\site-packages (1.0.0)
# Requirement already satisfied: texttable>=1.6.2 in c:\users\dell\anaconda3\envs\cryptography\lib\site-packages (from igraph) (1.7.0)

# %% [markdown]
# ---

# %% [markdown]
# ## Setup
#
# Install required library.

# %%
import polars as pl
import matplotlib.pyplot as plt
import igraph as ig

# df = pl.read_csv('data/HI-Small_Trans.csv')
df = pl.read_csv('data/HI-Small_Trans.csv')

# Sample only 10% of full data for memory management, commented out if want full data
df = df.sample(fraction=0.10, with_replacement=False, seed=42).lazy()

# %% [markdown]
# ---

# %% [markdown]
# ## Data Preparation
#
# Convert timestamp column to datetime format.

# %%
df.collect()
# Out:
# shape: (507_834, 11)
# ┌────────────┬───────────┬───────────┬─────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Timestamp  ┆ From Bank ┆ Account   ┆ To Bank ┆ … ┆ Amount    ┆ Payment   ┆ Payment   ┆ Is Launde │
# │ ---        ┆ ---       ┆ ---       ┆ ---     ┆   ┆ Paid      ┆ Currency  ┆ Format    ┆ ring      │
# │ str        ┆ i64       ┆ str       ┆ i64     ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │            ┆           ┆           ┆         ┆   ┆ f64       ┆ str       ┆ str       ┆ i64       │
# ╞════════════╪═══════════╪═══════════╪═════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2022/09/01 ┆ 122332    ┆ 808376670 ┆ 220504  ┆ … ┆ 165.58    ┆ UK Pound  ┆ Cash      ┆ 0         │
# │ 14:51      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022/09/02 ┆ 70        ┆ 100428660 ┆ 2843    ┆ … ┆ 1000.0    ┆ US Dollar ┆ Cheque    ┆ 0         │
# │ 12:05      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022/09/07 ┆ 14        ┆ 8035A5A50 ┆ 3       ┆ … ┆ 4449.0    ┆ Yuan      ┆ Credit    ┆ 0         │
# │ 22:23      ┆           ┆           ┆         ┆   ┆           ┆           ┆ Card      ┆           │
# │ 2022/09/02 ┆ 14290     ┆ 8028B20E0 ┆ 214100  ┆ … ┆ 24022.22  ┆ Euro      ┆ ACH       ┆ 0         │
# │ 15:44      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022/09/01 ┆ 12735     ┆ 803109B90 ┆ 226951  ┆ … ┆ 2777.01   ┆ US Dollar ┆ Cheque    ┆ 0         │
# │ 00:28      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ …         ┆ …         ┆ …       ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2022/09/06 ┆ 124       ┆ 813B87B71 ┆ 124     ┆ … ┆ 0.026602  ┆ Bitcoin   ┆ Bitcoin   ┆ 0         │
# │ 20:48      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022/09/02 ┆ 70        ┆ 1004286A8 ┆ 111141  ┆ … ┆ 1614.02   ┆ Euro      ┆ Cash      ┆ 0         │
# │ 01:05      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022/09/09 ┆ 12381     ┆ 8085123D0 ┆ 216645  ┆ … ┆ 320.56    ┆ US Dollar ┆ Credit    ┆ 0         │
# │ 12:46      ┆           ┆           ┆         ┆   ┆           ┆           ┆ Card      ┆           │
# │ 2022/09/08 ┆ 220       ┆ 8006B0F10 ┆ 214615  ┆ … ┆ 1648.87   ┆ US Dollar ┆ Cheque    ┆ 0         │
# │ 16:02      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022/09/09 ┆ 254910    ┆ 8142466C1 ┆ 54219   ┆ … ┆ 0.481134  ┆ Bitcoin   ┆ Bitcoin   ┆ 0         │
# │ 06:23      ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# └────────────┴───────────┴───────────┴─────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
df = df.with_columns(
    pl.col('Timestamp').str.strptime(pl.Datetime, format='%Y/%m/%d %H:%M')
)

# %% [markdown]
# ---

# %% [markdown]
# Drop transaction with Payment Format "Reinvesment" and Transaction from one account to the same account

# %%
df = df.filter(pl.col("Payment Format") != "Reinvestment").filter(pl.col("Account") != pl.col("Account_duplicated_0"))

# %%
df.collect()
# Out:
# shape: (448_736, 11)
# ┌────────────┬───────────┬───────────┬─────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Timestamp  ┆ From Bank ┆ Account   ┆ To Bank ┆ … ┆ Amount    ┆ Payment   ┆ Payment   ┆ Is Launde │
# │ ---        ┆ ---       ┆ ---       ┆ ---     ┆   ┆ Paid      ┆ Currency  ┆ Format    ┆ ring      │
# │ datetime[μ ┆ i64       ┆ str       ┆ i64     ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ s]         ┆           ┆           ┆         ┆   ┆ f64       ┆ str       ┆ str       ┆ i64       │
# ╞════════════╪═══════════╪═══════════╪═════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2022-09-01 ┆ 122332    ┆ 808376670 ┆ 220504  ┆ … ┆ 165.58    ┆ UK Pound  ┆ Cash      ┆ 0         │
# │ 14:51:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022-09-02 ┆ 70        ┆ 100428660 ┆ 2843    ┆ … ┆ 1000.0    ┆ US Dollar ┆ Cheque    ┆ 0         │
# │ 12:05:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022-09-07 ┆ 14        ┆ 8035A5A50 ┆ 3       ┆ … ┆ 4449.0    ┆ Yuan      ┆ Credit    ┆ 0         │
# │ 22:23:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆ Card      ┆           │
# │ 2022-09-02 ┆ 14290     ┆ 8028B20E0 ┆ 214100  ┆ … ┆ 24022.22  ┆ Euro      ┆ ACH       ┆ 0         │
# │ 15:44:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022-09-01 ┆ 12735     ┆ 803109B90 ┆ 226951  ┆ … ┆ 2777.01   ┆ US Dollar ┆ Cheque    ┆ 0         │
# │ 00:28:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ …         ┆ …         ┆ …       ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2022-09-04 ┆ 8354      ┆ 8064E6650 ┆ 3242    ┆ … ┆ 111.41    ┆ US Dollar ┆ Cash      ┆ 0         │
# │ 11:12:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022-09-02 ┆ 70        ┆ 1004286A8 ┆ 111141  ┆ … ┆ 1614.02   ┆ Euro      ┆ Cash      ┆ 0         │
# │ 01:05:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022-09-09 ┆ 12381     ┆ 8085123D0 ┆ 216645  ┆ … ┆ 320.56    ┆ US Dollar ┆ Credit    ┆ 0         │
# │ 12:46:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆ Card      ┆           │
# │ 2022-09-08 ┆ 220       ┆ 8006B0F10 ┆ 214615  ┆ … ┆ 1648.87   ┆ US Dollar ┆ Cheque    ┆ 0         │
# │ 16:02:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2022-09-09 ┆ 254910    ┆ 8142466C1 ┆ 54219   ┆ … ┆ 0.481134  ┆ Bitcoin   ┆ Bitcoin   ┆ 0         │
# │ 06:23:00   ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# └────────────┴───────────┴───────────┴─────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ---

# %% [markdown]
# ## Temporal View Graph Initialization

# %% [markdown]
# ### Create Nodes
#
# Build graph nodes from transactions with ID, sender, receiver, time, amount, and label.

# %%
nodes = df.with_row_index("node_id").select([
    pl.col("node_id"),
    pl.col("Account").alias("f_i"),                # From
    pl.col("Account_duplicated_0").alias("b_i"),   # Beneficiary
    pl.col("Timestamp").alias("t_i"),              # Time
    pl.col("Amount Received").alias("a_i"),        # Amount
    pl.col("Is Laundering")                        # Ground truth
])

# %%
nodes.collect()
# Out:
# shape: (448_736, 6)
# ┌─────────┬───────────┬───────────┬─────────────────────┬──────────┬───────────────┐
# │ node_id ┆ f_i       ┆ b_i       ┆ t_i                 ┆ a_i      ┆ Is Laundering │
# │ ---     ┆ ---       ┆ ---       ┆ ---                 ┆ ---      ┆ ---           │
# │ u32     ┆ str       ┆ str       ┆ datetime[μs]        ┆ f64      ┆ i64           │
# ╞═════════╪═══════════╪═══════════╪═════════════════════╪══════════╪═══════════════╡
# │ 0       ┆ 808376670 ┆ 808763050 ┆ 2022-09-01 14:51:00 ┆ 165.58   ┆ 0             │
# │ 1       ┆ 100428660 ┆ 800C08F10 ┆ 2022-09-02 12:05:00 ┆ 1000.0   ┆ 0             │
# │ 2       ┆ 8035A5A50 ┆ 8035CB140 ┆ 2022-09-07 22:23:00 ┆ 4449.0   ┆ 0             │
# │ 3       ┆ 8028B20E0 ┆ 80B5A8EF0 ┆ 2022-09-02 15:44:00 ┆ 24022.22 ┆ 0             │
# │ 4       ┆ 803109B90 ┆ 80A633740 ┆ 2022-09-01 00:28:00 ┆ 2777.01  ┆ 0             │
# │ …       ┆ …         ┆ …         ┆ …                   ┆ …        ┆ …             │
# │ 448731  ┆ 8064E6650 ┆ 808CA8BB0 ┆ 2022-09-04 11:12:00 ┆ 111.41   ┆ 0             │
# │ 448732  ┆ 1004286A8 ┆ 8144DAE90 ┆ 2022-09-02 01:05:00 ┆ 1614.02  ┆ 0             │
# │ 448733  ┆ 8085123D0 ┆ 80F2F2D50 ┆ 2022-09-09 12:46:00 ┆ 320.56   ┆ 0             │
# │ 448734  ┆ 8006B0F10 ┆ 805EE4920 ┆ 2022-09-08 16:02:00 ┆ 1648.87  ┆ 0             │
# │ 448735  ┆ 8142466C1 ┆ 81473B861 ┆ 2022-09-09 06:23:00 ┆ 0.481134 ┆ 0             │
# └─────────┴───────────┴───────────┴─────────────────────┴──────────┴───────────────┘

# %% [markdown]
# ---

# %% [markdown]
# ### Create Edges
#
# Connect transactions where one receiver becomes the sender in another transaction.

# %%
edges = nodes.join(
    nodes,
    left_on="b_i", 
    right_on="f_i",
    suffix="_d",
    how="inner"
).rename({"node_id": "v_s", "node_id_d": "v_d"})

# %%
edges.collect()
# Out:
# shape: (3_458_615, 11)
# ┌────────┬───────────┬───────────┬─────────────┬───┬───────────┬────────────┬─────────┬────────────┐
# │ v_s    ┆ f_i       ┆ b_i       ┆ t_i         ┆ … ┆ b_i_d     ┆ t_i_d      ┆ a_i_d   ┆ Is Launder │
# │ ---    ┆ ---       ┆ ---       ┆ ---         ┆   ┆ ---       ┆ ---        ┆ ---     ┆ ing_d      │
# │ u32    ┆ str       ┆ str       ┆ datetime[μs ┆   ┆ str       ┆ datetime[μ ┆ f64     ┆ ---        │
# │        ┆           ┆           ┆ ]           ┆   ┆           ┆ s]         ┆         ┆ i64        │
# ╞════════╪═══════════╪═══════════╪═════════════╪═══╪═══════════╪════════════╪═════════╪════════════╡
# │ 96927  ┆ 100428810 ┆ 808376670 ┆ 2022-09-10  ┆ … ┆ 808763050 ┆ 2022-09-01 ┆ 165.58  ┆ 0          │
# │        ┆           ┆           ┆ 12:26:00    ┆   ┆           ┆ 14:51:00   ┆         ┆            │
# │ 219894 ┆ 8076829F0 ┆ 808376670 ┆ 2022-09-02  ┆ … ┆ 808763050 ┆ 2022-09-01 ┆ 165.58  ┆ 0          │
# │        ┆           ┆           ┆ 18:32:00    ┆   ┆           ┆ 14:51:00   ┆         ┆            │
# │ 274253 ┆ 100428810 ┆ 808376670 ┆ 2022-09-04  ┆ … ┆ 808763050 ┆ 2022-09-01 ┆ 165.58  ┆ 0          │
# │        ┆           ┆           ┆ 08:28:00    ┆   ┆           ┆ 14:51:00   ┆         ┆            │
# │ 293035 ┆ 100428810 ┆ 808376670 ┆ 2022-09-02  ┆ … ┆ 808763050 ┆ 2022-09-01 ┆ 165.58  ┆ 0          │
# │        ┆           ┆           ┆ 01:56:00    ┆   ┆           ┆ 14:51:00   ┆         ┆            │
# │ 13047  ┆ 80571C290 ┆ 100428660 ┆ 2022-09-09  ┆ … ┆ 800C08F10 ┆ 2022-09-02 ┆ 1000.0  ┆ 0          │
# │        ┆           ┆           ┆ 06:35:00    ┆   ┆           ┆ 12:05:00   ┆         ┆            │
# │ …      ┆ …         ┆ …         ┆ …           ┆ … ┆ …         ┆ …          ┆ …       ┆ …          │
# │ 440264 ┆ 805836AE0 ┆ 1004286A8 ┆ 2022-09-09  ┆ … ┆ 8144DAE90 ┆ 2022-09-02 ┆ 1614.02 ┆ 0          │
# │        ┆           ┆           ┆ 16:27:00    ┆   ┆           ┆ 01:05:00   ┆         ┆            │
# │ 443201 ┆ 803BA4C60 ┆ 1004286A8 ┆ 2022-09-02  ┆ … ┆ 8144DAE90 ┆ 2022-09-02 ┆ 1614.02 ┆ 0          │
# │        ┆           ┆           ┆ 13:23:00    ┆   ┆           ┆ 01:05:00   ┆         ┆            │
# │ 67950  ┆ 801F49CC0 ┆ 8085123D0 ┆ 2022-09-08  ┆ … ┆ 80F2F2D50 ┆ 2022-09-09 ┆ 320.56  ┆ 0          │
# │        ┆           ┆           ┆ 00:56:00    ┆   ┆           ┆ 12:46:00   ┆         ┆            │
# │ 208836 ┆ 801F49CC0 ┆ 8085123D0 ┆ 2022-09-06  ┆ … ┆ 80F2F2D50 ┆ 2022-09-09 ┆ 320.56  ┆ 0          │
# │        ┆           ┆           ┆ 04:06:00    ┆   ┆           ┆ 12:46:00   ┆         ┆            │
# │ 446537 ┆ 800582620 ┆ 8006B0F10 ┆ 2022-09-03  ┆ … ┆ 805EE4920 ┆ 2022-09-08 ┆ 1648.87 ┆ 0          │
# │        ┆           ┆           ┆ 22:23:00    ┆   ┆           ┆ 16:02:00   ┆         ┆            │
# └────────┴───────────┴───────────┴─────────────┴───┴───────────┴────────────┴─────────┴────────────┘

# %% [markdown]
# ---

# %% [markdown]
# ### Filter Edges
#
# Keep only edges where the second transaction occurs within 24 hours after the first.

# %%
timedelta = pl.duration(hours=24)

# %%
edges = edges.filter(
    (pl.col("t_i_d") > pl.col("t_i")) & 
    (pl.col("t_i_d") < pl.col("t_i") + timedelta)
)

# %% [markdown]
# ---

# %% [markdown]
# ### Temporal View Results
#
# Display final nodes and edges.

# %%
print(nodes.collect())
# Out:
# shape: (448_736, 6)
# ┌─────────┬───────────┬───────────┬─────────────────────┬──────────┬───────────────┐
# │ node_id ┆ f_i       ┆ b_i       ┆ t_i                 ┆ a_i      ┆ Is Laundering │
# │ ---     ┆ ---       ┆ ---       ┆ ---                 ┆ ---      ┆ ---           │
# │ u32     ┆ str       ┆ str       ┆ datetime[μs]        ┆ f64      ┆ i64           │
# ╞═════════╪═══════════╪═══════════╪═════════════════════╪══════════╪═══════════════╡
# │ 0       ┆ 808376670 ┆ 808763050 ┆ 2022-09-01 14:51:00 ┆ 165.58   ┆ 0             │
# │ 1       ┆ 100428660 ┆ 800C08F10 ┆ 2022-09-02 12:05:00 ┆ 1000.0   ┆ 0             │
# │ 2       ┆ 8035A5A50 ┆ 8035CB140 ┆ 2022-09-07 22:23:00 ┆ 4449.0   ┆ 0             │
# │ 3       ┆ 8028B20E0 ┆ 80B5A8EF0 ┆ 2022-09-02 15:44:00 ┆ 24022.22 ┆ 0             │
# │ 4       ┆ 803109B90 ┆ 80A633740 ┆ 2022-09-01 00:28:00 ┆ 2777.01  ┆ 0             │
# │ …       ┆ …         ┆ …         ┆ …                   ┆ …        ┆ …             │
# │ 448731  ┆ 8064E6650 ┆ 808CA8BB0 ┆ 2022-09-04 11:12:00 ┆ 111.41   ┆ 0             │
# │ 448732  ┆ 1004286A8 ┆ 8144DAE90 ┆ 2022-09-02 01:05:00 ┆ 1614.02  ┆ 0             │
# │ 448733  ┆ 8085123D0 ┆ 80F2F2D50 ┆ 2022-09-09 12:46:00 ┆ 320.56   ┆ 0             │
# │ 448734  ┆ 8006B0F10 ┆ 805EE4920 ┆ 2022-09-08 16:02:00 ┆ 1648.87  ┆ 0             │
# │ 448735  ┆ 8142466C1 ┆ 81473B861 ┆ 2022-09-09 06:23:00 ┆ 0.481134 ┆ 0             │
# └─────────┴───────────┴───────────┴─────────────────────┴──────────┴───────────────┘

# %%
print(edges.select(["v_s", "v_d", "t_i", "t_i_d"]).collect())
# Out:
# shape: (342_658, 4)
# ┌────────┬────────┬─────────────────────┬─────────────────────┐
# │ v_s    ┆ v_d    ┆ t_i                 ┆ t_i_d               │
# │ ---    ┆ ---    ┆ ---                 ┆ ---                 │
# │ u32    ┆ u32    ┆ datetime[μs]        ┆ datetime[μs]        │
# ╞════════╪════════╪═════════════════════╪═════════════════════╡
# │ 15338  ┆ 1      ┆ 2022-09-02 09:51:00 ┆ 2022-09-02 12:05:00 │
# │ 17484  ┆ 1      ┆ 2022-09-02 10:00:00 ┆ 2022-09-02 12:05:00 │
# │ 49381  ┆ 1      ┆ 2022-09-02 07:18:00 ┆ 2022-09-02 12:05:00 │
# │ 76094  ┆ 1      ┆ 2022-09-02 07:35:00 ┆ 2022-09-02 12:05:00 │
# │ 76372  ┆ 1      ┆ 2022-09-02 02:02:00 ┆ 2022-09-02 12:05:00 │
# │ …      ┆ …      ┆ …                   ┆ …                   │
# │ 440264 ┆ 448730 ┆ 2022-09-09 16:27:00 ┆ 2022-09-10 13:08:00 │
# │ 212057 ┆ 448732 ┆ 2022-09-02 00:29:00 ┆ 2022-09-02 01:05:00 │
# │ 253082 ┆ 448732 ┆ 2022-09-02 00:08:00 ┆ 2022-09-02 01:05:00 │
# │ 340467 ┆ 448732 ┆ 2022-09-02 00:44:00 ┆ 2022-09-02 01:05:00 │
# │ 414642 ┆ 448732 ┆ 2022-09-02 00:19:00 ┆ 2022-09-02 01:05:00 │
# └────────┴────────┴─────────────────────┴─────────────────────┘

# %% [markdown]
# ---

# %% [markdown]
# ## Second Order Graph Creation

# %% [markdown]
# ### Edge creation

# %% [markdown]
# create a second order graph edges from Temporal graph's edges, simulating where one node of Second Order Graph represent one whole transaction

# %%
s_edges = edges.with_columns([
    pl.concat_str([pl.col("f_i"), pl.col("b_i")], separator="->").alias("v_s"),
    pl.concat_str([pl.col("b_i"), pl.col("b_i_d")], separator="->").alias("v_d")
]).select(["v_s", "v_d"])

# %%
s_edges.collect()
# Out:
# shape: (342_658, 2)
# ┌──────────────────────┬──────────────────────┐
# │ v_s                  ┆ v_d                  │
# │ ---                  ┆ ---                  │
# │ str                  ┆ str                  │
# ╞══════════════════════╪══════════════════════╡
# │ 81269FE50->100428660 ┆ 100428660->800C08F10 │
# │ 8070EAE50->100428660 ┆ 100428660->800C08F10 │
# │ 806018480->100428660 ┆ 100428660->800C08F10 │
# │ 80D167C20->100428660 ┆ 100428660->800C08F10 │
# │ 80C710A10->100428660 ┆ 100428660->800C08F10 │
# │ …                    ┆ …                    │
# │ 805836AE0->1004286A8 ┆ 1004286A8->80DEC81F0 │
# │ 8093BB640->1004286A8 ┆ 1004286A8->8144DAE90 │
# │ 80E2EFCF0->1004286A8 ┆ 1004286A8->8144DAE90 │
# │ 811645990->1004286A8 ┆ 1004286A8->8144DAE90 │
# │ 802DDEDC0->1004286A8 ┆ 1004286A8->8144DAE90 │
# └──────────────────────┴──────────────────────┘

# %% [markdown]
# ---

# %% [markdown]
# ### Weight Calculation

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Count times where one node goes to another
s_edges_with_count = s_edges.group_by(["v_s", "v_d"]).agg([
    pl.len().alias("spec_count")
])

denom_P = s_edges.group_by("v_s").agg([
    pl.len().alias("s_to_any")
])

denom_P_prime = s_edges.group_by("v_d").agg([
    pl.len().alias("any_to_d")
])

# %%
print(s_edges_with_count.collect())
# Out:
# shape: (299_827, 3)
# ┌──────────────────────┬──────────────────────┬────────────┐
# │ v_s                  ┆ v_d                  ┆ spec_count │
# │ ---                  ┆ ---                  ┆ ---        │
# │ str                  ┆ str                  ┆ u32        │
# ╞══════════════════════╪══════════════════════╪════════════╡
# │ 801BB1D80->100428660 ┆ 100428660->800DBAF00 ┆ 1          │
# │ 804E06B40->100428660 ┆ 100428660->810E63370 ┆ 1          │
# │ 80F3261C0->80F31A6E0 ┆ 80F31A6E0->80FCE2440 ┆ 1          │
# │ 801736690->100428660 ┆ 100428660->801940410 ┆ 2          │
# │ 8017504D0->811971A40 ┆ 811971A40->8127150E0 ┆ 2          │
# │ …                    ┆ …                    ┆ …          │
# │ 8066DDFC0->100428660 ┆ 100428660->801CF6A90 ┆ 1          │
# │ 80FF494D0->100428660 ┆ 100428660->800D0F970 ┆ 1          │
# │ 8070C40B0->100428660 ┆ 100428660->80103A930 ┆ 1          │
# │ 805A380A0->100428660 ┆ 100428660->80109B6D0 ┆ 1          │
# │ 80FF494D0->100428660 ┆ 100428660->80202A360 ┆ 1          │
# └──────────────────────┴──────────────────────┴────────────┘

# %%
print(denom_P.collect().head())

print(denom_P_prime.collect().head())
# Out:
# shape: (5, 2)
# ┌──────────────────────┬──────────┐
# │ v_s                  ┆ s_to_any │
# │ ---                  ┆ ---      │
# │ str                  ┆ u32      │
# ╞══════════════════════╪══════════╡
# │ 1004286A8->801D1D400 ┆ 2        │
# │ 80140C0E0->802FDB4C0 ┆ 2        │
# │ 801A147B0->801ACF2D0 ┆ 2        │
# │ 8010812E0->81096F380 ┆ 1        │
# │ 80028DE60->8003293E0 ┆ 1        │
# └──────────────────────┴──────────┘
# shape: (5, 2)
# ┌──────────────────────┬──────────┐
# │ v_d                  ┆ any_to_d │
# │ ---                  ┆ ---      │
# │ str                  ┆ u32      │
# ╞══════════════════════╪══════════╡
# │ 80A19B890->80A9CAF40 ┆ 2        │
# │ 8104B3E50->811710740 ┆ 3        │
# │ 803A621E0->803F400C0 ┆ 2        │
# │ 80BAADCB0->813B98840 ┆ 1        │
# │ 800E0BEC0->8022833A0 ┆ 1        │
# └──────────────────────┴──────────┘

# %%
s_edges_with_weight = s_edges_with_count.join(
    denom_P,
    on="v_s",
    how="left"
).join(
    denom_P_prime,
    on="v_d",
    how="left"
).with_columns([
    (pl.col("spec_count") / pl.col("s_to_any")).alias("P"),
    (pl.col("spec_count") / pl.col("any_to_d")).alias("P_prime")
]).with_columns([
    (pl.max_horizontal([pl.col("P"), pl.col("P_prime")])).alias("weight")
])

# %%
print(s_edges_with_weight.collect().head())
# Out:
# shape: (5, 8)
# ┌───────────────┬──────────────┬────────────┬──────────┬──────────┬──────────┬──────────┬──────────┐
# │ v_s           ┆ v_d          ┆ spec_count ┆ s_to_any ┆ any_to_d ┆ P        ┆ P_prime  ┆ weight   │
# │ ---           ┆ ---          ┆ ---        ┆ ---      ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ str           ┆ str          ┆ u32        ┆ u32      ┆ u32      ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════════════╪══════════════╪════════════╪══════════╪══════════╪══════════╪══════════╪══════════╡
# │ 809935FA0->10 ┆ 100428660->8 ┆ 1          ┆ 2485     ┆ 36       ┆ 0.000402 ┆ 0.027778 ┆ 0.027778 │
# │ 0428660       ┆ 018A3F90     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 80AA7AC90->10 ┆ 100428660->8 ┆ 1          ┆ 1535     ┆ 50       ┆ 0.000651 ┆ 0.02     ┆ 0.02     │
# │ 0428660       ┆ 047DE280     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 806793EC0->80 ┆ 8070F3C70->8 ┆ 2          ┆ 2        ┆ 2        ┆ 1.0      ┆ 1.0      ┆ 1.0      │
# │ 70F3C70       ┆ 0E2C73A0     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 802163E70->80 ┆ 802166980->8 ┆ 1          ┆ 3        ┆ 1        ┆ 0.333333 ┆ 1.0      ┆ 1.0      │
# │ 2166980       ┆ 03005950     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 8042A4FB0->10 ┆ 100428660->8 ┆ 1          ┆ 1868     ┆ 49       ┆ 0.000535 ┆ 0.020408 ┆ 0.020408 │
# │ 0428660       ┆ 0F38BBB0     ┆            ┆          ┆          ┆          ┆          ┆          │
# └───────────────┴──────────────┴────────────┴──────────┴──────────┴──────────┴──────────┴──────────┘

# %% [markdown]
# ---

# %% [markdown]
# ### Sanity Checking Second Order Graph

# %%
edges.collect().shape, s_edges_with_weight.collect().shape
# Out:
# ((342658, 11), (299827, 8))

# %%
weights = s_edges_with_weight.select("weight").collect().to_numpy().flatten()
plt.hist(weights, bins=50, edgecolor='black')
plt.xlabel('Weight')
plt.ylabel('Frequency')
plt.title('Weight Distribution')
plt.show()

# %%
# P vs P_prime scatter plot (should see which dominates)
data = s_edges_with_weight.select(["P", "P_prime", "weight"]).collect()
plt.scatter(data["P"], data["P_prime"], alpha=0.5)
plt.plot([0, 1], [0, 1], 'r--')  # diagonal line
plt.xlabel('P')
plt.ylabel("P'")
plt.title("P vs P' Distribution")
# Out:
# Text(0.5, 1.0, "P vs P' Distribution")

# %%
s_edges_with_weight.collect()
# Out:
# shape: (299_827, 8)
# ┌───────────────┬──────────────┬────────────┬──────────┬──────────┬──────────┬──────────┬──────────┐
# │ v_s           ┆ v_d          ┆ spec_count ┆ s_to_any ┆ any_to_d ┆ P        ┆ P_prime  ┆ weight   │
# │ ---           ┆ ---          ┆ ---        ┆ ---      ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ str           ┆ str          ┆ u32        ┆ u32      ┆ u32      ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════════════╪══════════════╪════════════╪══════════╪══════════╪══════════╪══════════╪══════════╡
# │ 805B88890->10 ┆ 100428660->8 ┆ 1          ┆ 2070     ┆ 19       ┆ 0.000483 ┆ 0.052632 ┆ 0.052632 │
# │ 0428660       ┆ 0B863560     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 8025B0610->80 ┆ 80D67AC40->8 ┆ 1          ┆ 1        ┆ 1        ┆ 1.0      ┆ 1.0      ┆ 1.0      │
# │ D67AC40       ┆ 0E6ED3C0     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 80D1D5E80->10 ┆ 100428660->8 ┆ 2          ┆ 935      ┆ 101      ┆ 0.002139 ┆ 0.019802 ┆ 0.019802 │
# │ 0428660       ┆ 099F0360     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 8048D7570->10 ┆ 1004286A8->8 ┆ 1          ┆ 1476     ┆ 28       ┆ 0.000678 ┆ 0.035714 ┆ 0.035714 │
# │ 04286A8       ┆ 042C4340     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 8060F9200->10 ┆ 100428660->8 ┆ 1          ┆ 1278     ┆ 54       ┆ 0.000782 ┆ 0.018519 ┆ 0.018519 │
# │ 0428660       ┆ 06A54EB0     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ …             ┆ …            ┆ …          ┆ …        ┆ …        ┆ …        ┆ …        ┆ …        │
# │ 805A380A0->10 ┆ 100428660->8 ┆ 1          ┆ 1914     ┆ 62       ┆ 0.000522 ┆ 0.016129 ┆ 0.016129 │
# │ 0428660       ┆ 08E8D160     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 813A643A0->10 ┆ 100428660->8 ┆ 2          ┆ 1824     ┆ 146      ┆ 0.001096 ┆ 0.013699 ┆ 0.013699 │
# │ 0428660       ┆ 0C0F3540     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 802991E50->10 ┆ 1004286A8->8 ┆ 2          ┆ 1132     ┆ 67       ┆ 0.001767 ┆ 0.029851 ┆ 0.029851 │
# │ 04286A8       ┆ 0C25FE70     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 80E26B080->10 ┆ 100428660->8 ┆ 1          ┆ 883      ┆ 64       ┆ 0.001133 ┆ 0.015625 ┆ 0.015625 │
# │ 0428660       ┆ 0C855DD0     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 806018480->10 ┆ 100428660->8 ┆ 2          ┆ 2045     ┆ 68       ┆ 0.000978 ┆ 0.029412 ┆ 0.029412 │
# │ 0428660       ┆ 08A77AD0     ┆            ┆          ┆          ┆          ┆          ┆          │
# └───────────────┴──────────────┴────────────┴──────────┴──────────┴──────────┴──────────┴──────────┘

# %% [markdown]
# ---

# %% [markdown]
# ### Apply second order graph's weight to Temporal graph's edges

# %%
edges_with_weight = edges.with_columns([
    pl.concat_str([pl.col("f_i"), pl.col("b_i")], separator="->").alias("tx_s"),
    pl.concat_str([pl.col("b_i"), pl.col("b_i_d")], separator="->").alias("tx_d")
]).join(
    s_edges_with_weight.select([
        "v_s", "v_d", "weight"
    ]),
    left_on=["tx_s", "tx_d"],
    right_on=["v_s", "v_d"],
    how="left"
# )
).drop([
    "tx_s", "tx_d"
])

# %%
print(s_edges_with_weight.collect())
# Out:
# shape: (299_827, 8)
# ┌───────────────┬──────────────┬────────────┬──────────┬──────────┬──────────┬──────────┬──────────┐
# │ v_s           ┆ v_d          ┆ spec_count ┆ s_to_any ┆ any_to_d ┆ P        ┆ P_prime  ┆ weight   │
# │ ---           ┆ ---          ┆ ---        ┆ ---      ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ str           ┆ str          ┆ u32        ┆ u32      ┆ u32      ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════════════╪══════════════╪════════════╪══════════╪══════════╪══════════╪══════════╪══════════╡
# │ 800146310->80 ┆ 800254F80->8 ┆ 1          ┆ 5        ┆ 1        ┆ 0.2      ┆ 1.0      ┆ 1.0      │
# │ 0254F80       ┆ 01ABE400     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 809F5A2A0->80 ┆ 80B1BF360->8 ┆ 1          ┆ 2        ┆ 1        ┆ 0.5      ┆ 1.0      ┆ 1.0      │
# │ B1BF360       ┆ 0C0458E0     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 807FEDED0->10 ┆ 100428660->8 ┆ 1          ┆ 2083     ┆ 95       ┆ 0.00048  ┆ 0.010526 ┆ 0.010526 │
# │ 0428660       ┆ 04D2BBF0     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 8051CA650->10 ┆ 100428660->8 ┆ 1          ┆ 1775     ┆ 40       ┆ 0.000563 ┆ 0.025    ┆ 0.025    │
# │ 0428660       ┆ 08350930     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 80E2EFCF0->10 ┆ 1004286A8->8 ┆ 1          ┆ 2276     ┆ 40       ┆ 0.000439 ┆ 0.025    ┆ 0.025    │
# │ 04286A8       ┆ 02589E50     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ …             ┆ …            ┆ …          ┆ …        ┆ …        ┆ …        ┆ …        ┆ …        │
# │ 8042A4FB0->10 ┆ 100428660->8 ┆ 1          ┆ 1868     ┆ 59       ┆ 0.000535 ┆ 0.016949 ┆ 0.016949 │
# │ 0428660       ┆ 06698FE0     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 8070EAE50->10 ┆ 100428660->8 ┆ 1          ┆ 1876     ┆ 32       ┆ 0.000533 ┆ 0.03125  ┆ 0.03125  │
# │ 0428660       ┆ 0B5EE1F0     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 8001AD4E0->10 ┆ 1004286A8->8 ┆ 1          ┆ 1300     ┆ 11       ┆ 0.000769 ┆ 0.090909 ┆ 0.090909 │
# │ 04286A8       ┆ 00EBFCB0     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 8133EAE70->10 ┆ 100428660->8 ┆ 1          ┆ 4164     ┆ 30       ┆ 0.00024  ┆ 0.033333 ┆ 0.033333 │
# │ 0428660       ┆ 07F8D980     ┆            ┆          ┆          ┆          ┆          ┆          │
# │ 808DC6CF0->10 ┆ 100428810->8 ┆ 1          ┆ 186      ┆ 7        ┆ 0.005376 ┆ 0.142857 ┆ 0.142857 │
# │ 0428810       ┆ 089256F0     ┆            ┆          ┆          ┆          ┆          ┆          │
# └───────────────┴──────────────┴────────────┴──────────┴──────────┴──────────┴──────────┴──────────┘

# %% [markdown]
# ---

# %% [markdown]
# ## Community Detection with Leiden

# %%
edges_with_weight.collect().filter(pl.col("Is Laundering") == 1)
# Out:
# shape: (87, 12)
# ┌────────┬───────────┬───────────┬─────────────┬───┬─────────────┬──────────┬─────────────┬────────┐
# │ v_s    ┆ f_i       ┆ b_i       ┆ t_i         ┆ … ┆ t_i_d       ┆ a_i_d    ┆ Is Launderi ┆ weight │
# │ ---    ┆ ---       ┆ ---       ┆ ---         ┆   ┆ ---         ┆ ---      ┆ ng_d        ┆ ---    │
# │ u32    ┆ str       ┆ str       ┆ datetime[μs ┆   ┆ datetime[μs ┆ f64      ┆ ---         ┆ f64    │
# │        ┆           ┆           ┆ ]           ┆   ┆ ]           ┆          ┆ i64         ┆        │
# ╞════════╪═══════════╪═══════════╪═════════════╪═══╪═════════════╪══════════╪═════════════╪════════╡
# │ 124772 ┆ 100428660 ┆ 800704A30 ┆ 2022-09-06  ┆ … ┆ 2022-09-07  ┆ 212.95   ┆ 0           ┆ 1.0    │
# │        ┆           ┆           ┆ 16:52:00    ┆   ┆ 09:52:00    ┆          ┆             ┆        │
# │ 308926 ┆ 80018E990 ┆ 800059C00 ┆ 2022-09-08  ┆ … ┆ 2022-09-08  ┆ 1518.21  ┆ 0           ┆ 1.0    │
# │        ┆           ┆           ┆ 13:14:00    ┆   ┆ 14:22:00    ┆          ┆             ┆        │
# │ 5364   ┆ 8001BB380 ┆ 8001A6870 ┆ 2022-09-01  ┆ … ┆ 2022-09-01  ┆ 29.05    ┆ 0           ┆ 1.0    │
# │        ┆           ┆           ┆ 17:48:00    ┆   ┆ 20:46:00    ┆          ┆             ┆        │
# │ 129376 ┆ 804B56250 ┆ 807C35490 ┆ 2022-09-06  ┆ … ┆ 2022-09-07  ┆ 1223.72  ┆ 0           ┆ 1.0    │
# │        ┆           ┆           ┆ 14:55:00    ┆   ┆ 12:53:00    ┆          ┆             ┆        │
# │ 410465 ┆ 100428660 ┆ 800EEA500 ┆ 2022-09-06  ┆ … ┆ 2022-09-07  ┆ 2259.8   ┆ 0           ┆ 1.0    │
# │        ┆           ┆           ┆ 11:14:00    ┆   ┆ 03:13:00    ┆          ┆             ┆        │
# │ …      ┆ …         ┆ …         ┆ …           ┆ … ┆ …           ┆ …        ┆ …           ┆ …      │
# │ 145    ┆ 8021353D0 ┆ 80266F880 ┆ 2022-09-09  ┆ … ┆ 2022-09-10  ┆ 9783.49  ┆ 0           ┆ 1.0    │
# │        ┆           ┆           ┆ 09:47:00    ┆   ┆ 02:27:00    ┆          ┆             ┆        │
# │ 44803  ┆ 8061A6010 ┆ 806C62690 ┆ 2022-09-06  ┆ … ┆ 2022-09-07  ┆ 3.6226e6 ┆ 0           ┆ 1.0    │
# │        ┆           ┆           ┆ 13:24:00    ┆   ┆ 04:14:00    ┆          ┆             ┆        │
# │ 234843 ┆ 80777E5C0 ┆ 800E3D880 ┆ 2022-09-06  ┆ … ┆ 2022-09-07  ┆ 1135.38  ┆ 0           ┆ 1.0    │
# │        ┆           ┆           ┆ 17:05:00    ┆   ┆ 06:36:00    ┆          ┆             ┆        │
# │ 51050  ┆ 812A09CF0 ┆ 812A09D40 ┆ 2022-09-11  ┆ … ┆ 2022-09-12  ┆ 52144.81 ┆ 1           ┆ 1.0    │
# │        ┆           ┆           ┆ 17:12:00    ┆   ┆ 10:44:00    ┆          ┆             ┆        │
# │ 23162  ┆ 80154AAF0 ┆ 80069EE60 ┆ 2022-09-08  ┆ … ┆ 2022-09-09  ┆ 11.25    ┆ 0           ┆ 1.0    │
# │        ┆           ┆           ┆ 07:04:00    ┆   ┆ 04:48:00    ┆          ┆             ┆        │
# └────────┴───────────┴───────────┴─────────────┴───┴─────────────┴──────────┴─────────────┴────────┘

# %%
edges_with_weight.collect().filter(pl.col("Is Laundering") == 1)["weight"].value_counts().sort("weight")
# Out:
# shape: (3, 2)
# ┌──────────┬───────┐
# │ weight   ┆ count │
# │ ---      ┆ ---   │
# │ f64      ┆ u32   │
# ╞══════════╪═══════╡
# │ 0.333333 ┆ 1     │
# │ 0.5      ┆ 2     │
# │ 1.0      ┆ 84    │
# └──────────┴───────┘

# %%
edges_with_weight.collect().filter(pl.col("Is Laundering") == 0)["weight"].value_counts().sort("weight")
# Out:
# shape: (330, 2)
# ┌──────────┬───────┐
# │ weight   ┆ count │
# │ ---      ┆ ---   │
# │ f64      ┆ u32   │
# ╞══════════╪═══════╡
# │ 0.004202 ┆ 20    │
# │ 0.004329 ┆ 12    │
# │ 0.00463  ┆ 18    │
# │ 0.005155 ┆ 63    │
# │ 0.005319 ┆ 25    │
# │ …        ┆ …     │
# │ 0.8      ┆ 220   │
# │ 0.833333 ┆ 75    │
# │ 0.857143 ┆ 54    │
# │ 0.875    ┆ 14    │
# │ 1.0      ┆ 67462 │
# └──────────┴───────┘

# %%
df_for_leiden = edges_with_weight.select([
    pl.concat_str(["f_i", "b_i", "t_i"]).alias("source_node"),
    pl.concat_str(["b_i", "b_i_d", "t_i_d"]).alias("target_node"),
    pl.col("weight")
])

# %%
df_for_leiden.collect()
# Out:
# shape: (342_658, 3)
# ┌─────────────────────────────────┬─────────────────────────────────┬──────────┐
# │ source_node                     ┆ target_node                     ┆ weight   │
# │ ---                             ┆ ---                             ┆ ---      │
# │ str                             ┆ str                             ┆ f64      │
# ╞═════════════════════════════════╪═════════════════════════════════╪══════════╡
# │ 81269FE501004286602022-09-02 0… ┆ 100428660800C08F102022-09-02 1… ┆ 0.041667 │
# │ 8070EAE501004286602022-09-02 1… ┆ 100428660800C08F102022-09-02 1… ┆ 0.041667 │
# │ 8060184801004286602022-09-02 0… ┆ 100428660800C08F102022-09-02 1… ┆ 0.041667 │
# │ 80D167C201004286602022-09-02 0… ┆ 100428660800C08F102022-09-02 1… ┆ 0.041667 │
# │ 80C710A101004286602022-09-02 0… ┆ 100428660800C08F102022-09-02 1… ┆ 0.041667 │
# │ …                               ┆ …                               ┆ …        │
# │ 805836AE01004286A82022-09-09 1… ┆ 1004286A880DEC81F02022-09-10 1… ┆ 0.066667 │
# │ 8093BB6401004286A82022-09-02 0… ┆ 1004286A88144DAE902022-09-02 0… ┆ 0.25     │
# │ 80E2EFCF01004286A82022-09-02 0… ┆ 1004286A88144DAE902022-09-02 0… ┆ 0.25     │
# │ 8116459901004286A82022-09-02 0… ┆ 1004286A88144DAE902022-09-02 0… ┆ 0.25     │
# │ 802DDEDC01004286A82022-09-02 0… ┆ 1004286A88144DAE902022-09-02 0… ┆ 0.25     │
# └─────────────────────────────────┴─────────────────────────────────┴──────────┘

# %%
df_for_leiden_with_weight_filtered = df_for_leiden.filter(pl.col("weight") >= 0.5)

# %%
df_for_leiden_with_weight_filtered.collect()
# Out:
# shape: (75_146, 3)
# ┌─────────────────────────────────┬─────────────────────────────────┬────────┐
# │ source_node                     ┆ target_node                     ┆ weight │
# │ ---                             ┆ ---                             ┆ ---    │
# │ str                             ┆ str                             ┆ f64    │
# ╞═════════════════════════════════╪═════════════════════════════════╪════════╡
# │ 8001A84608001E5B002022-09-08 0… ┆ 8001E5B00800A36BC02022-09-08 1… ┆ 1.0    │
# │ 80979071080F2938C02022-09-08 1… ┆ 80F2938C08104648502022-09-09 0… ┆ 1.0    │
# │ 800284530800798B002022-09-06 1… ┆ 800798B008009E68A02022-09-07 1… ┆ 1.0    │
# │ 8005DBC308017C91C02022-09-07 1… ┆ 8017C91C0802E2DAE02022-09-08 1… ┆ 1.0    │
# │ 8090F74E08091977702022-09-01 1… ┆ 80919777080924BA002022-09-02 0… ┆ 1.0    │
# │ …                               ┆ …                               ┆ …      │
# │ 100428660807276BC02022-09-08 2… ┆ 807276BC0808D7CE602022-09-09 0… ┆ 1.0    │
# │ 80E1A3C5080E23FCD02022-09-01 1… ┆ 80E23FCD080E7EB7E02022-09-02 1… ┆ 1.0    │
# │ 80E868AD080F1238A02022-09-01 2… ┆ 80F1238A080F479BB02022-09-02 0… ┆ 1.0    │
# │ 80E868AD080F1238A02022-09-02 0… ┆ 80F1238A080F479BB02022-09-02 0… ┆ 1.0    │
# │ 8000C76D080F1238A02022-09-01 0… ┆ 80F1238A080F479BB02022-09-02 0… ┆ 1.0    │
# └─────────────────────────────────┴─────────────────────────────────┴────────┘

# %%
edges_data = df_for_leiden_with_weight_filtered.select([
    "source_node", "target_node", "weight"
]).collect().to_numpy()

# %%
g = ig.Graph.TupleList(edges_data, directed=True, weights=True)

# %%
partition = g.community_leiden(weights='weight', objective_function='modularity')

# %%
partition

# %%
# Create a mapping of Transaction ID -> Community ID
node_names = g.vs["name"]
community_ids = partition.membership

community_df = pl.LazyFrame({
    "node_id_str": node_names,
    "community_id": community_ids
})

# %%
community_df.collect().head()
# Out:
# shape: (5, 2)
# ┌─────────────────────────────────┬──────────────┐
# │ node_id_str                     ┆ community_id │
# │ ---                             ┆ ---          │
# │ str                             ┆ i64          │
# ╞═════════════════════════════════╪══════════════╡
# │ 8001A84608001E5B002022-09-08 0… ┆ 0            │
# │ 8001E5B00800A36BC02022-09-08 1… ┆ 0            │
# │ 80979071080F2938C02022-09-08 1… ┆ 1            │
# │ 80F2938C08104648502022-09-09 0… ┆ 1            │
# │ 800284530800798B002022-09-06 1… ┆ 2            │
# └─────────────────────────────────┴──────────────┘

# %% [markdown]
# ---

# %% [markdown]
# ## Anomalous Communities Detection

# %% [markdown]
# ### Applying Community ID back to Temporal Node

# %%
nodes_with_community = nodes.with_columns([
    pl.concat_str([pl.col("f_i"), pl.col("b_i"), pl.col("t_i")]).alias("node_id_str")
]).join(
    community_df,
    on="node_id_str",
    how="left"
).drop("node_id_str")

# %%
nodes_with_community.collect()
# Out:
# shape: (448_736, 7)
# ┌─────────┬───────────┬───────────┬─────────────────────┬──────────┬───────────────┬──────────────┐
# │ node_id ┆ f_i       ┆ b_i       ┆ t_i                 ┆ a_i      ┆ Is Laundering ┆ community_id │
# │ ---     ┆ ---       ┆ ---       ┆ ---                 ┆ ---      ┆ ---           ┆ ---          │
# │ u32     ┆ str       ┆ str       ┆ datetime[μs]        ┆ f64      ┆ i64           ┆ i64          │
# ╞═════════╪═══════════╪═══════════╪═════════════════════╪══════════╪═══════════════╪══════════════╡
# │ 0       ┆ 808376670 ┆ 808763050 ┆ 2022-09-01 14:51:00 ┆ 165.58   ┆ 0             ┆ null         │
# │ 1       ┆ 100428660 ┆ 800C08F10 ┆ 2022-09-02 12:05:00 ┆ 1000.0   ┆ 0             ┆ 28550        │
# │ 2       ┆ 8035A5A50 ┆ 8035CB140 ┆ 2022-09-07 22:23:00 ┆ 4449.0   ┆ 0             ┆ null         │
# │ 3       ┆ 8028B20E0 ┆ 80B5A8EF0 ┆ 2022-09-02 15:44:00 ┆ 24022.22 ┆ 0             ┆ null         │
# │ 4       ┆ 803109B90 ┆ 80A633740 ┆ 2022-09-01 00:28:00 ┆ 2777.01  ┆ 0             ┆ null         │
# │ …       ┆ …         ┆ …         ┆ …                   ┆ …        ┆ …             ┆ …            │
# │ 448731  ┆ 8064E6650 ┆ 808CA8BB0 ┆ 2022-09-04 11:12:00 ┆ 111.41   ┆ 0             ┆ null         │
# │ 448732  ┆ 1004286A8 ┆ 8144DAE90 ┆ 2022-09-02 01:05:00 ┆ 1614.02  ┆ 0             ┆ null         │
# │ 448733  ┆ 8085123D0 ┆ 80F2F2D50 ┆ 2022-09-09 12:46:00 ┆ 320.56   ┆ 0             ┆ null         │
# │ 448734  ┆ 8006B0F10 ┆ 805EE4920 ┆ 2022-09-08 16:02:00 ┆ 1648.87  ┆ 0             ┆ null         │
# │ 448735  ┆ 8142466C1 ┆ 81473B861 ┆ 2022-09-09 06:23:00 ┆ 0.481134 ┆ 0             ┆ null         │
# └─────────┴───────────┴───────────┴─────────────────────┴──────────┴───────────────┴──────────────┘

# %%
#count nodes that has community_id not null
nodes_with_community.collect().filter(pl.col("community_id").is_not_null()).shape, nodes_with_community.collect().filter(pl.col("community_id").is_null()).shape
# Out:
# ((110664, 7), (338072, 7))

# %%
# group by account in f_i and b_i to see how many unique community ids each account is involved in
f_i_communities = nodes_with_community.select([
    pl.col("f_i").alias("account"),
    pl.col("community_id")
]).filter(pl.col("community_id").is_not_null()
).unique().group_by("account").agg([
    pl.col("community_id").n_unique().alias("unique_communities")
])

b_i_communities = nodes_with_community.select([
    pl.col("b_i").alias("account"),
    pl.col("community_id")
]).filter(pl.col("community_id").is_not_null()).unique().group_by("account").agg([
    pl.col("community_id").n_unique().alias("unique_communities")
])

# %%
# merge f_i and b_i community counts
account_communities = pl.concat([f_i_communities, b_i_communities]).group_by("account").agg([
    pl.col("unique_communities").sum().alias("total_unique_communities")
])

# %%
account_communities.collect().shape
# Out:
# (86580, 2)

# %%
# count accounts in original df
unique_acc_left = df.select(pl.col("Account")).unique().collect().shape
unique_acc_right = df.select(pl.col("Account_duplicated_0")).unique().collect().shape

all_accounts = pl.concat([
    df.select(pl.col("Account").alias("account")),
    df.select(pl.col("Account_duplicated_0").alias("account"))
]).unique().collect()

# %%
all_accounts.shape
# Out:
# (242652, 1)

# %% [markdown]
# ---

# %% [markdown]
# ### Community features extraction

# %% [markdown]
# - Community Edges Features

# %%
edges_with_weight.collect().head()
# Out:
# shape: (5, 12)
# ┌───────┬───────────┬───────────┬──────────────┬───┬─────────────┬────────┬─────────────┬──────────┐
# │ v_s   ┆ f_i       ┆ b_i       ┆ t_i          ┆ … ┆ t_i_d       ┆ a_i_d  ┆ Is Launderi ┆ weight   │
# │ ---   ┆ ---       ┆ ---       ┆ ---          ┆   ┆ ---         ┆ ---    ┆ ng_d        ┆ ---      │
# │ u32   ┆ str       ┆ str       ┆ datetime[μs] ┆   ┆ datetime[μs ┆ f64    ┆ ---         ┆ f64      │
# │       ┆           ┆           ┆              ┆   ┆ ]           ┆        ┆ i64         ┆          │
# ╞═══════╪═══════════╪═══════════╪══════════════╪═══╪═════════════╪════════╪═════════════╪══════════╡
# │ 15338 ┆ 81269FE50 ┆ 100428660 ┆ 2022-09-02   ┆ … ┆ 2022-09-02  ┆ 1000.0 ┆ 0           ┆ 0.041667 │
# │       ┆           ┆           ┆ 09:51:00     ┆   ┆ 12:05:00    ┆        ┆             ┆          │
# │ 17484 ┆ 8070EAE50 ┆ 100428660 ┆ 2022-09-02   ┆ … ┆ 2022-09-02  ┆ 1000.0 ┆ 0           ┆ 0.041667 │
# │       ┆           ┆           ┆ 10:00:00     ┆   ┆ 12:05:00    ┆        ┆             ┆          │
# │ 49381 ┆ 806018480 ┆ 100428660 ┆ 2022-09-02   ┆ … ┆ 2022-09-02  ┆ 1000.0 ┆ 0           ┆ 0.041667 │
# │       ┆           ┆           ┆ 07:18:00     ┆   ┆ 12:05:00    ┆        ┆             ┆          │
# │ 76094 ┆ 80D167C20 ┆ 100428660 ┆ 2022-09-02   ┆ … ┆ 2022-09-02  ┆ 1000.0 ┆ 0           ┆ 0.041667 │
# │       ┆           ┆           ┆ 07:35:00     ┆   ┆ 12:05:00    ┆        ┆             ┆          │
# │ 76372 ┆ 80C710A10 ┆ 100428660 ┆ 2022-09-02   ┆ … ┆ 2022-09-02  ┆ 1000.0 ┆ 0           ┆ 0.041667 │
# │       ┆           ┆           ┆ 02:02:00     ┆   ┆ 12:05:00    ┆        ┆             ┆          │
# └───────┴───────────┴───────────┴──────────────┴───┴─────────────┴────────┴─────────────┴──────────┘

# %%
edges_with_weight.select(pl.len()).collect().item()
# Out:
# 342658

# %%
edges_out_degrees = edges_with_weight.with_columns([
    pl.col("v_s").alias("node_id")
]).group_by("node_id").agg([
    pl.len().alias("tx_out_degree")
])

edges_in_degrees = edges_with_weight.with_columns([
    pl.col("v_d").alias("node_id")
]).group_by("node_id").agg([
    pl.len().alias("tx_in_degree")
])

# %%
edges_in_degrees.collect().head()
# Out:
# shape: (5, 2)
# ┌─────────┬──────────────┐
# │ node_id ┆ tx_in_degree │
# │ ---     ┆ ---          │
# │ u32     ┆ u32          │
# ╞═════════╪══════════════╡
# │ 30824   ┆ 1            │
# │ 291804  ┆ 1            │
# │ 76701   ┆ 1            │
# │ 267411  ┆ 3            │
# │ 73030   ┆ 1            │
# └─────────┴──────────────┘

# %%
edges_features = edges_with_weight.join(
    nodes_with_community.select([
        pl.col("node_id").alias("v_s"),
        pl.col("community_id").alias("community_id_s")
    ]),
    how="left",
    on="v_s"
).join(
    nodes_with_community.select([
        pl.col("node_id").alias("v_d"),
        pl.col("community_id").alias("community_id_d")
    ]),
    how="left",
    on="v_d"
).filter(
    pl.col("community_id_s") == pl.col("community_id_d")
).drop([
    "community_id_d"
])

# %%
edges_with_weight.collect().shape, edges_features.collect().shape
# Out:
# ((342658, 12), (75269, 13))

# %%
edges_features = edges_features.join(
    edges_in_degrees,
    left_on="v_d",
    right_on="node_id",
    how="left"
# )
).join(
    edges_out_degrees,
    left_on="v_s",
    right_on="node_id",
    how="left"
)

# %%
edges_features.collect().head()
# Out:
# shape: (5, 15)
# ┌────────┬───────────┬───────────┬─────────────┬───┬────────┬────────────┬────────────┬────────────┐
# │ v_s    ┆ f_i       ┆ b_i       ┆ t_i         ┆ … ┆ weight ┆ community_ ┆ tx_in_degr ┆ tx_out_deg │
# │ ---    ┆ ---       ┆ ---       ┆ ---         ┆   ┆ ---    ┆ id_s       ┆ ee         ┆ ree        │
# │ u32    ┆ str       ┆ str       ┆ datetime[μs ┆   ┆ f64    ┆ ---        ┆ ---        ┆ ---        │
# │        ┆           ┆           ┆ ]           ┆   ┆        ┆ i64        ┆ u32        ┆ u32        │
# ╞════════╪═══════════╪═══════════╪═════════════╪═══╪════════╪════════════╪════════════╪════════════╡
# │ 371063 ┆ 8001A8460 ┆ 8001E5B00 ┆ 2022-09-08  ┆ … ┆ 1.0    ┆ 0          ┆ 1          ┆ 3          │
# │        ┆           ┆           ┆ 07:32:00    ┆   ┆        ┆            ┆            ┆            │
# │ 45572  ┆ 809790710 ┆ 80F2938C0 ┆ 2022-09-08  ┆ … ┆ 1.0    ┆ 1          ┆ 1          ┆ 1          │
# │        ┆           ┆           ┆ 10:00:00    ┆   ┆        ┆            ┆            ┆            │
# │ 149517 ┆ 800284530 ┆ 800798B00 ┆ 2022-09-06  ┆ … ┆ 1.0    ┆ 2          ┆ 1          ┆ 3          │
# │        ┆           ┆           ┆ 17:02:00    ┆   ┆        ┆            ┆            ┆            │
# │ 395304 ┆ 8005DBC30 ┆ 8017C91C0 ┆ 2022-09-07  ┆ … ┆ 1.0    ┆ 3          ┆ 1          ┆ 1          │
# │        ┆           ┆           ┆ 19:40:00    ┆   ┆        ┆            ┆            ┆            │
# │ 131807 ┆ 8090F74E0 ┆ 809197770 ┆ 2022-09-01  ┆ … ┆ 1.0    ┆ 4          ┆ 1          ┆ 2          │
# │        ┆           ┆           ┆ 13:37:00    ┆   ┆        ┆            ┆            ┆            │
# └────────┴───────────┴───────────┴─────────────┴───┴────────┴────────────┴────────────┴────────────┘

# %%
edges_features = edges_features.group_by("community_id_s").agg([
    pl.len().alias("num_edges"),
    pl.col("weight").mean().alias("avg_edge_weight"),
    pl.col("tx_in_degree").sum().alias("total_tx_in_degree"),
    pl.col("tx_out_degree").sum().alias("total_tx_out_degree"),
]).rename({
    "community_id_s": "community_id"
})

# %%
edges_features.collect().head()
# Out:
# shape: (5, 5)
# ┌──────────────┬───────────┬─────────────────┬────────────────────┬─────────────────────┐
# │ community_id ┆ num_edges ┆ avg_edge_weight ┆ total_tx_in_degree ┆ total_tx_out_degree │
# │ ---          ┆ ---       ┆ ---             ┆ ---                ┆ ---                 │
# │ i64          ┆ u32       ┆ f64             ┆ u32                ┆ u32                 │
# ╞══════════════╪═══════════╪═════════════════╪════════════════════╪═════════════════════╡
# │ 396          ┆ 2         ┆ 1.0             ┆ 2                  ┆ 2                   │
# │ 34742        ┆ 1         ┆ 1.0             ┆ 1                  ┆ 1                   │
# │ 17706        ┆ 1         ┆ 1.0             ┆ 1                  ┆ 1                   │
# │ 10096        ┆ 10        ┆ 1.0             ┆ 20                 ┆ 20                  │
# │ 10772        ┆ 1         ┆ 1.0             ┆ 1                  ┆ 1                   │
# └──────────────┴───────────┴─────────────────┴────────────────────┴─────────────────────┘

# %% [markdown]
# - Structure features

# %%
nodes_with_community.collect().head()
# Out:
# shape: (5, 7)
# ┌─────────┬───────────┬───────────┬─────────────────────┬──────────┬───────────────┬──────────────┐
# │ node_id ┆ f_i       ┆ b_i       ┆ t_i                 ┆ a_i      ┆ Is Laundering ┆ community_id │
# │ ---     ┆ ---       ┆ ---       ┆ ---                 ┆ ---      ┆ ---           ┆ ---          │
# │ u32     ┆ str       ┆ str       ┆ datetime[μs]        ┆ f64      ┆ i64           ┆ i64          │
# ╞═════════╪═══════════╪═══════════╪═════════════════════╪══════════╪═══════════════╪══════════════╡
# │ 0       ┆ 808376670 ┆ 808763050 ┆ 2022-09-01 14:51:00 ┆ 165.58   ┆ 0             ┆ null         │
# │ 1       ┆ 100428660 ┆ 800C08F10 ┆ 2022-09-02 12:05:00 ┆ 1000.0   ┆ 0             ┆ 28550        │
# │ 2       ┆ 8035A5A50 ┆ 8035CB140 ┆ 2022-09-07 22:23:00 ┆ 4449.0   ┆ 0             ┆ null         │
# │ 3       ┆ 8028B20E0 ┆ 80B5A8EF0 ┆ 2022-09-02 15:44:00 ┆ 24022.22 ┆ 0             ┆ null         │
# │ 4       ┆ 803109B90 ┆ 80A633740 ┆ 2022-09-01 00:28:00 ┆ 2777.01  ┆ 0             ┆ null         │
# └─────────┴───────────┴───────────┴─────────────────────┴──────────┴───────────────┴──────────────┘

# %%
# aggregate community features including number of transactions in each community, number of edges, total / average amount, average edge weight, in/out degree
community_features = nodes_with_community.group_by("community_id").agg([
    pl.len().alias("transactions_count"),
    pl.sum("a_i").alias("total_amount"),
    pl.mean("a_i").alias("average_amount"),
    pl.min("t_i").alias("first_transaction_time"),
    pl.max("t_i").alias("last_transaction_time"),
]).join(
    edges_features,
    left_on="community_id",
    right_on="community_id",
    how="left"
).cast({
    "transactions_count": pl.Int32,
    "num_edges": pl.Int32,
    "total_tx_in_degree": pl.Int32,
    "total_tx_out_degree": pl.Int32,
}).with_columns([
    (pl.col("last_transaction_time") - pl.col("first_transaction_time")).alias("active_duration"),
    (pl.col("total_tx_in_degree") - pl.col("total_tx_out_degree")).abs().alias("degree_imbalance"),
])

# %%
community_features.collect()
# Out:
# shape: (39_003, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ community ┆ transacti ┆ total_amo ┆ average_a ┆ … ┆ total_tx_ ┆ active_du ┆ avg_amoun ┆ degree_i │
# │ _id       ┆ ons_count ┆ unt       ┆ mount     ┆   ┆ out_degre ┆ ration    ┆ t_per_tx  ┆ mbalance │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ e         ┆ ---       ┆ ---       ┆ ---      │
# │ i64       ┆ i32       ┆ f64       ┆ f64       ┆   ┆ ---       ┆ duration[ ┆ f64       ┆ i32      │
# │           ┆           ┆           ┆           ┆   ┆ i32       ┆ μs]       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 34093     ┆ 4         ┆ 2.4437e7  ┆ 6.1091e6  ┆ … ┆ 8         ┆ 5h 47m    ┆ 6.1091e6  ┆ 0        │
# │ 16795     ┆ 2         ┆ 7618.2    ┆ 3809.1    ┆ … ┆ 1         ┆ 21h 49m   ┆ 3809.1    ┆ 0        │
# │ 32655     ┆ 2         ┆ 12738.49  ┆ 6369.245  ┆ … ┆ 1         ┆ 23h 6m    ┆ 6369.245  ┆ 0        │
# │ 536       ┆ 5         ┆ 3.7698e7  ┆ 7.5397e6  ┆ … ┆ 11        ┆ 23h 24m   ┆ 7.5397e6  ┆ 4        │
# │ 23994     ┆ 4         ┆ 3404.62   ┆ 851.155   ┆ … ┆ 9         ┆ 15h 42m   ┆ 851.155   ┆ 6        │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 18602     ┆ 2         ┆ 5167.35   ┆ 2583.675  ┆ … ┆ 1         ┆ 17h 22m   ┆ 2583.675  ┆ 0        │
# │ 23854     ┆ 2         ┆ 7440.38   ┆ 3720.19   ┆ … ┆ 1         ┆ 22h 35m   ┆ 3720.19   ┆ 0        │
# │ 33158     ┆ 2         ┆ 1.7119e8  ┆ 8.5595e7  ┆ … ┆ 1         ┆ 23h 3m    ┆ 8.5595e7  ┆ 0        │
# │ 22395     ┆ 4         ┆ 254308.25 ┆ 63577.062 ┆ … ┆ 6         ┆ 11h 34m   ┆ 63577.062 ┆ 0        │
# │           ┆           ┆           ┆ 5         ┆   ┆           ┆           ┆ 5         ┆          │
# │ 19921     ┆ 3         ┆ 206601.82 ┆ 68867.273 ┆ … ┆ 4         ┆ 19h 37m   ┆ 68867.273 ┆ 2        │
# │           ┆           ┆           ┆ 333       ┆   ┆           ┆           ┆ 333       ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# ---

# %% [markdown]
# ### Calculate hold time per account to compute for communities

# %%
events = pl.concat(
    [
        nodes_with_community.select(
            pl.col("b_i").alias("account"),
            pl.col("t_i"),
            pl.col("community_id").alias("community"),
            pl.col("Is Laundering"),
            pl.lit("in").alias("dir"),
        ),
        nodes_with_community.select(
            pl.col("f_i").alias("account"),
            pl.col("t_i"),
            pl.col("community_id").alias("community"),
            pl.col("Is Laundering"),
            pl.lit("out").alias("dir"),
        ),
    ],
    how="vertical",
)

hold_times = (
    events
    .sort(["account", "t_i"])
    .with_columns([
        pl.col("t_i").shift(-1).over("account").alias("next_t"),
        pl.col("dir").shift(-1).over("account").alias("next_dir"),
    ])
    # We should consider about the edge case that the account is still holding onto the money so we should fill next_t with time.now() or smth
    .filter(
        (pl.col("dir") == "in") &
        (pl.col("next_dir") == "out")
    )
    .with_columns(
        (pl.col("next_t") - pl.col("t_i")).alias("hold_time")
    )
)

account_features = (
    hold_times
    # .filter(pl.col("community").is_not_null())
    .group_by("account")
    .agg([
        pl.col("hold_time").mean().alias("avg_hold_time"),
        pl.len().alias("num_hold_events"),
        pl.col("Is Laundering").max().alias("Is Laundering"),
        pl.col("community").implode().alias("communities")
    ])
)

# %%
community_hold_times = account_features.explode("communities").rename({
    "communities": "community"
}).group_by("community").agg([
    pl.col("avg_hold_time").mean().alias("community_avg_hold_time"),
])

# %%
community_hold_times.collect().head()
# Out:
# shape: (5, 2)
# ┌───────────┬─────────────────────────┐
# │ community ┆ community_avg_hold_time │
# │ ---       ┆ ---                     │
# │ i64       ┆ duration[μs]            │
# ╞═══════════╪═════════════════════════╡
# │ 15226     ┆ 16h 50m 45s             │
# │ 32134     ┆ 2d 21h 21m 30s          │
# │ 35659     ┆ 8h 32m 30s              │
# │ 17843     ┆ 1d 10h 2m 30s           │
# │ 9310      ┆ 18h 18m 33s             │
# └───────────┴─────────────────────────┘

# %%
# plot histogram of avg_hold_time
# convert duration to numeric (hours) to avoid dtype issues in plt.hist
avg_hold_time_hours = (
	community_hold_times
	.select((pl.col("community_avg_hold_time").dt.total_seconds() / 3600).alias("community_avg_hold_time_hours"))
	.collect()
	.to_numpy()
	.flatten()
)

plt.hist(avg_hold_time_hours, bins=50, edgecolor='black')
plt.xlabel('Average Hold Time For Communities (hours)')
plt.ylabel('Frequency')
plt.title('Average Hold Time Distribution')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Checking Accounts involving in Fraud transaction Hold Time Distribution

# %%
account_features.filter(pl.col("Is Laundering") == 1).collect()
# Out:
# shape: (98, 5)
# ┌───────────┬───────────────┬─────────────────┬───────────────┬──────────────┐
# │ account   ┆ avg_hold_time ┆ num_hold_events ┆ Is Laundering ┆ communities  │
# │ ---       ┆ ---           ┆ ---             ┆ ---           ┆ ---          │
# │ str       ┆ duration[μs]  ┆ u32             ┆ i64           ┆ list[i64]    │
# ╞═══════════╪═══════════════╪═════════════════╪═══════════════╪══════════════╡
# │ 800051110 ┆ 1d 1h 7m      ┆ 1               ┆ 1             ┆ [null]       │
# │ 800059C00 ┆ 6m            ┆ 1               ┆ 1             ┆ [3032]       │
# │ 800061E50 ┆ 18h 48m       ┆ 1               ┆ 1             ┆ [35249]      │
# │ 800093C80 ┆ 1h 1m         ┆ 1               ┆ 1             ┆ [10994]      │
# │ 8000B8AB0 ┆ 4d 15h 38m    ┆ 1               ┆ 1             ┆ [4921]       │
# │ …         ┆ …             ┆ …               ┆ …             ┆ …            │
# │ 812A09D40 ┆ 17h 32m       ┆ 1               ┆ 1             ┆ [38561]      │
# │ 812D0C600 ┆ 2d 4h 21m     ┆ 1               ┆ 1             ┆ [null]       │
# │ 812D22980 ┆ 18h 13m       ┆ 1               ┆ 1             ┆ [17672]      │
# │ 813DA9E11 ┆ 6h 58m        ┆ 1               ┆ 1             ┆ [15365]      │
# │ 81454A1C1 ┆ 1d 52m 30s    ┆ 2               ┆ 1             ┆ [9668, null] │
# └───────────┴───────────────┴─────────────────┴───────────────┴──────────────┘

# %%
avg_hold_time_hours = (
	account_features.filter(pl.col("Is Laundering") == 1)
	.select((pl.col("avg_hold_time").dt.total_seconds() / 3600).alias("avg_hold_time_hours"))
	.collect()
	.to_numpy()
	.flatten()
)

plt.hist(avg_hold_time_hours, bins=50, edgecolor='black')
plt.xlabel('Average Hold Time For Laundering Accounts (hours)')
plt.ylabel('Frequency')
plt.title('Average Hold Time Distribution')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Finalize community features

# %%
community_features = community_features.with_columns([
    (pl.col("num_edges") / pl.col("transactions_count")).alias("edge_density"),
]).join(
    community_hold_times,
    left_on="community_id",
    right_on="community"
)

# %%
community_features.collect().head()
# Out:
# shape: (5, 15)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ community ┆ transacti ┆ total_amo ┆ average_a ┆ … ┆ avg_amoun ┆ degree_im ┆ edge_dens ┆ communit │
# │ _id       ┆ ons_count ┆ unt       ┆ mount     ┆   ┆ t_per_tx  ┆ balance   ┆ ity       ┆ y_avg_ho │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ld_time  │
# │ i64       ┆ i32       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ i32       ┆ f64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ duration │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ [μs]     │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 27275     ┆ 2         ┆ 17844.21  ┆ 8922.105  ┆ … ┆ 8922.105  ┆ 0         ┆ 0.5       ┆ 9h 38m   │
# │ 29892     ┆ 2         ┆ 2715.69   ┆ 1357.845  ┆ … ┆ 1357.845  ┆ 0         ┆ 0.5       ┆ 14h 14m  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 40s      │
# │ 1188      ┆ 3         ┆ 22893.82  ┆ 7631.2733 ┆ … ┆ 7631.2733 ┆ 2         ┆ 0.666667  ┆ 7h 41m   │
# │           ┆           ┆           ┆ 33        ┆   ┆ 33        ┆           ┆           ┆          │
# │ 6303      ┆ 4         ┆ 378655.36 ┆ 94663.84  ┆ … ┆ 94663.84  ┆ 2         ┆ 0.75      ┆ 1d 5h    │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 24m 40s  │
# │ 11668     ┆ 2         ┆ 2053.81   ┆ 1026.905  ┆ … ┆ 1026.905  ┆ 0         ┆ 0.5       ┆ 17h 49m  │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# ---

# %% [markdown]
# ## Classifying Communities

# %% [markdown]
# ### Rule based approach

# %% [markdown]
# - Low Hold Time Flag

# %%
# If community average hold time is in the lowest 10th percentile, set low_hold_time_flag to 2, else 0
community_hold_time_10th_percentile = community_hold_times.select(
    pl.col("community_avg_hold_time").quantile(0.1)
).collect().item()

community_features = community_features.with_columns([
    ((pl.col("community_avg_hold_time") < community_hold_time_10th_percentile).cast(pl.Int8) * 2).alias("low_hold_time_flag")
])

# %%
# plot histogram of community_features with low_hold_time_flag count
low_count = community_features.group_by("low_hold_time_flag").agg([
    pl.len().alias("count")
])

plt.bar(
    low_count.select("low_hold_time_flag").collect().to_numpy().flatten(),
    low_count.select("count").collect().to_numpy().flatten()
)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# ---

# %% [markdown]
# - Edge Density

# %%
# If community edge density is in the highest 90th percentile, set high_edge_density_flag to 2, else 0
edge_density_90th_percentile = community_features.select(
    pl.col("edge_density").quantile(0.9)
).collect().item()

community_features = community_features.with_columns([
    ((pl.col("edge_density") > edge_density_90th_percentile).cast(pl.Int8) * 2).alias("high_edge_density_flag")
])

# %%
# plot bar chart of high_edge_density_flag counts
high_edge_density_count = community_features.group_by("high_edge_density_flag").agg([
    pl.len().alias("count")
])

plt.bar(
    high_edge_density_count.select("high_edge_density_flag").collect().to_numpy().flatten(),
    high_edge_density_count.select("count").collect().to_numpy().flatten()
)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# ---

# %% [markdown]
# - Short-lived burst activity

# %%
# If community active duration is in the lowest 10th percentile, set short_active_duration_flag to 1, else 0
community_active_duration_10th_percentile = community_features.select(
    pl.col("active_duration").quantile(0.1)
).collect().item()

community_features = community_features.with_columns([
    (pl.col("active_duration") < community_active_duration_10th_percentile).cast(pl.Int8).alias("short_active_duration_flag")
])

# %%
# plot bar chart of short_active_duration_flag counts
short_count = community_features.group_by("short_active_duration_flag").agg([
    pl.len().alias("count")
])

plt.bar(
    short_count.select("short_active_duration_flag").collect().to_numpy().flatten(),
    short_count.select("count").collect().to_numpy().flatten()
)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# ---

# %% [markdown]
# - Large amount per transaction

# %%
# If community average amount is in the highest 90th percentile, set high_amount_flag to 1, else 0
amount_90th_percentile = community_features.select(
    pl.col("average_amount").quantile(0.9)
).collect().item()

community_features = community_features.with_columns([
    (pl.col("average_amount") > amount_90th_percentile).cast(pl.Int8).alias("high_amount_flag")
])

# %%
# plot bar chart of high_amount_flag counts
high_count = community_features.group_by("high_amount_flag").agg([
    pl.len().alias("count")
])

plt.bar(
    high_count.select("high_amount_flag").collect().to_numpy().flatten(),
    high_count.select("count").collect().to_numpy().flatten()
)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# ---

# %% [markdown]
# - Degree imbalance

# %%
# If community degree imbalance is in the highest 90th percentile, set high_degree_imbalance_flag to 1, else 0
degree_imbalance_90th_percentile = community_features.select(
    pl.col("degree_imbalance").quantile(0.9)
).collect().item()

community_features = community_features.with_columns([
    (pl.col("degree_imbalance") > degree_imbalance_90th_percentile).cast(pl.Int8).alias("high_degree_imbalance_flag")
])

# %%
# plot histogram of community_avg_hold_time with high_degree_imbalance_flag count
high_count = community_features.group_by("high_degree_imbalance_flag").agg([
    pl.len().alias("count")
])

plt.bar(
    high_count.select("high_degree_imbalance_flag").collect().to_numpy().flatten(),
    high_count.select("count").collect().to_numpy().flatten()
)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# ---

# %% [markdown]
# ### Finalizing community risk scoring and classification

# %%
community_features = community_features.with_columns([
    pl.sum_horizontal([
        pl.col("low_hold_time_flag"),
        pl.col("short_active_duration_flag"),
        pl.col("high_amount_flag"),
        pl.col("high_degree_imbalance_flag"),
        pl.col("high_edge_density_flag")
    ]).alias("risk_score")
])

# %%
# plot histogram of community risk scores
risk_scores = community_features.select("risk_score").collect().to_numpy().flatten()
plt.hist(risk_scores, bins=range(int(risk_scores.max()) + 2), align='left', edgecolor='black')
plt.xlabel('Community Risk Score')
plt.ylabel('Frequency')
plt.title('Community Risk Score Distribution')
plt.show()

# %%
# if risk_score >= 3, label as suspicious
community_features = community_features.with_columns([
    (pl.col("risk_score") >= 3).cast(pl.Int8).alias("suspicious_flag")
])

# %%
community_features.collect().head()
# Out:
# shape: (5, 22)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ community ┆ transacti ┆ total_amo ┆ average_a ┆ … ┆ high_amou ┆ high_degr ┆ risk_scor ┆ suspicio │
# │ _id       ┆ ons_count ┆ unt       ┆ mount     ┆   ┆ nt_flag   ┆ ee_imbala ┆ e         ┆ us_flag  │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ nce_flag  ┆ ---       ┆ ---      │
# │ i64       ┆ i32       ┆ f64       ┆ f64       ┆   ┆ i8        ┆ ---       ┆ i8        ┆ i8       │
# │           ┆           ┆           ┆           ┆   ┆           ┆ i8        ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 1712      ┆ 4         ┆ 323496.63 ┆ 80874.157 ┆ … ┆ 0         ┆ 0         ┆ 2         ┆ 0        │
# │           ┆           ┆           ┆ 5         ┆   ┆           ┆           ┆           ┆          │
# │ 27397     ┆ 2         ┆ 497.6     ┆ 248.8     ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0        │
# │ 25566     ┆ 3         ┆ 6181.13   ┆ 2060.3766 ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0        │
# │           ┆           ┆           ┆ 67        ┆   ┆           ┆           ┆           ┆          │
# │ 35409     ┆ 2         ┆ 2973.38   ┆ 1486.69   ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0        │
# │ 6443      ┆ 3         ┆ 49463.74  ┆ 16487.913 ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0        │
# │           ┆           ┆           ┆ 333       ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# plot bar of suspicious communities
sus_count = community_features.group_by("suspicious_flag").agg([
    pl.len().alias("count")
])

sus_count.collect()
# Out:
# shape: (2, 2)
# ┌─────────────────┬───────┐
# │ suspicious_flag ┆ count │
# │ ---             ┆ ---   │
# │ i8              ┆ u32   │
# ╞═════════════════╪═══════╡
# │ 1               ┆ 4230  │
# │ 0               ┆ 34753 │
# └─────────────────┴───────┘

# %% [markdown]
# ## Account Level Risk scoring

# %% [markdown]
# ---
